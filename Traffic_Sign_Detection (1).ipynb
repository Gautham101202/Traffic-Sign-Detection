# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'road-sign-detection:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F671172%2F1181356%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240808%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240808T180343Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading road-sign-detection, 228716498 bytes compressed
# [==================================================] 228716498 bytes downloaded
# Downloaded and uncompressed: road-sign-detection
# Data source import complete.

# %% [markdown]
# ### Datasets and DataLoaders

# %%
# !pip install xmltodict
import os, cv2, random, xmltodict, torch, pandas as pd, numpy as np
from glob import glob
from PIL import Image
from torch.utils.data import random_split, Dataset, DataLoader
from matplotlib import pyplot as plt

class ObjectDetectionCustomDataset(Dataset):

    def __init__(self, root, transformations = None, size = 224, im_files = [".jpg", ".png", ".jpeg"]):

        self.root, self.size, self.transformations = root, size, transformations
        self.class_names, self.class_counts = {}, 0
        self.data_info = sorted(glob(f"{root}/annotations/*.xml"))

        for idx, data_info in enumerate(self.data_info):

            info = xmltodict.parse(open(f"{data_info}","r").read())

            bbox_info = info["annotation"]["object"]
            if isinstance(bbox_info, list):
                for bb_info in bbox_info:
                    if class_name not in self.class_names: self.class_names[class_name] = self.class_counts; self.class_counts += 1

            elif isinstance(bbox_info, dict):
                for bb_info in bbox_info:
                    class_name = bbox_info["name"]
                    if class_name not in self.class_names: self.class_names[class_name] = self.class_counts; self.class_counts += 1

    def __len__(self): return len(self.data_info)

    def get_info(self, idx): return xmltodict.parse(open(f"{self.data_info[idx]}","r").read())

    def read_im(self, info): return Image.open(f"{self.root}/images/{info['annotation']['filename']}").convert("RGB")

    def get_coordinates(self, bbox): return float(bbox["xmin"]), float(bbox["ymin"]), float(bbox["xmax"]), float(bbox["ymax"])

    def get_bboxes(self, info):

        bboxes, class_names = [], []
        bbox_info = info["annotation"]["object"]

        if isinstance(bbox_info, list):
            for bb_info in bbox_info:
                bbox = bb_info["bndbox"]
                class_name = bb_info["name"]
                class_names.append(class_name)
                bboxes.append(self.get_coordinates(bbox))

        elif isinstance(bbox_info, dict):
            for bb_info in bbox_info:
                if bb_info == "bndbox":
                    bbox = bbox_info[bb_info]
                    class_name = bbox_info["name"]
                    bboxes.append(self.get_coordinates(bbox))
                    class_names.append(class_name)

        return torch.as_tensor(bboxes, dtype = torch.float32), class_names

    def get_label(self, class_name): return self.class_names[class_name]

    def get_area(self, bboxes): return (bboxes[:, 3] - bboxes[:, 1]) * (bboxes[:, 2] - bboxes[:, 0])

    def create_target(self, bboxes, labels, picture_id, area, is_crowd): target = {}; target["boxes"] = bboxes; target["labels"] = labels; target["image_id"] = picture_id; target["area"] = area; target["iscrowd"] = is_crowd; return target

    def __getitem__(self, idx):

        info = self.get_info(idx)
        im = self.read_im(info)
        bboxes, class_names = self.get_bboxes(info)
        labels = torch.tensor([self.get_label(class_name) for class_name in class_names], dtype = torch.int64)

        picture_id = torch.tensor([idx])
        area = self.get_area(bboxes)
        is_crowd = torch.zeros((len(bboxes), ), dtype = torch.int64)

        target = self.create_target(bboxes, labels, picture_id, area, is_crowd)

        if self.transformations is not None: im, target = self.transformations(im, target)

        return im, target

def custom_collate_fn(batch): return tuple(zip(*batch))

def get_dls(root, transformations, bs, split = [0.8, 0.1], ns = 4):

    ds = ObjectDetectionCustomDataset(root = root, transformations = transformations)

    all_len = len(ds); tr_len = int(all_len * split[0]); val_len = int(all_len * split[1])
    tr_ds, val_ds, ts_ds = random_split(dataset = ds, lengths = [tr_len, val_len, all_len - tr_len - val_len])

    tr_dl, val_dl, ts_dl = DataLoader(tr_ds, batch_size = bs, collate_fn = custom_collate_fn, shuffle = True, num_workers = ns), DataLoader(val_ds, batch_size = bs, collate_fn = custom_collate_fn, shuffle = False, num_workers = ns), DataLoader(ts_ds, batch_size = 1, collate_fn = custom_collate_fn, shuffle = False, num_workers = ns)

    return tr_dl, val_dl, ts_dl, ds.class_names
# Out:
# Collecting xmltodict
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl.metadata (7.7 kB)
# Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.13.0

# %% [markdown]
# ### Transformations

# %%
from torch import Tensor
from torchvision.transforms import functional as F, transforms as T
from typing import Dict, Optional, Tuple, List

class Compose:
    def __init__(self, transforms):
        self.transforms = transforms

    def __call__(self, image, target):
        for t in self.transforms:
            image, target = t(image, target)
        return image, target

class PILToTensor(torch.nn.Module):
    def forward(
        self, image: Tensor, target: Optional[Dict[str, Tensor]] = None
    ) -> Tuple[Tensor, Optional[Dict[str, Tensor]]]:
        image = F.pil_to_tensor(image)
        return image, target

class Normalize(torch.nn.Module):
    def forward(self, image: Tensor, target: Optional, mean: List[float] = [0.485, 0.456, 0.406], std: List[float] = [0.229, 0.224, 0.225]):
        image = F.normalize(tensor = image, mean = mean, std = std)
        return image, target

class ConvertImageDtype(torch.nn.Module):
    def __init__(self, dtype: torch.dtype) -> None:
        super().__init__()
        self.dtype = dtype

    def forward(
        self, image: Tensor, target: Optional[Dict[str, Tensor]] = None
    ) -> Tuple[Tensor, Optional[Dict[str, Tensor]]]:
        image = F.convert_image_dtype(image, self.dtype)
        return image, target

class RandomHorizontalFlip(T.RandomHorizontalFlip):
    def forward(
        self, image: Tensor, target: Optional[Dict[str, Tensor]] = None
    ) -> Tuple[Tensor, Optional[Dict[str, Tensor]]]:
        if torch.rand(1) < self.p:
            image = F.hflip(image)
            if target is not None:
                _, _, width = F.get_dimensions(image)
                if "masks" in target:
                    target["masks"] = target["masks"].flip(-1)
                if "keypoints" in target:
                    keypoints = target["keypoints"]
                    keypoints = _flip_coco_person_keypoints(keypoints, width)
                    target["keypoints"] = keypoints
        return image, target

def get_transform(train):

    transformations = []
    transformations.append(PILToTensor())
    transformations.append(ConvertImageDtype(torch.float))
    transformations.append(Normalize())

    if train: transformations.append(RandomHorizontalFlip(0.5))

    return Compose(transformations)

tfs = get_transform(train = False)
data_path = "/kaggle/input/road-sign-detection"
tr_dl, val_dl, ts_dl, class_names = get_dls(root = data_path, transformations = tfs, bs = 4)
print(len(tr_dl), len(val_dl), len(ts_dl), class_names)
# Out:
# 176 22 89 {'trafficlight': 0, 'speedlimit': 1, 'crosswalk': 2, 'stop': 3}
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %% [markdown]
# ### Data Visualization

# %%
def tensor_2_im(t, t_type = "rgb", inv_trans = False):

    assert t_type in ["rgb", "gray"], "Specify if Image is grayscale or RGB."
    gray_tfs = T.Compose([T.Normalize(mean = [ 0.], std = [1/0.5]), T.Normalize(mean = [-0.5], std = [1])])
    rgb_tfs  = T.Compose([T.Normalize(mean = [ 0., 0., 0. ], std = [ 1/0.229, 1/0.224, 1/0.225 ]), T.Normalize(mean = [ -0.485, -0.456, -0.406 ], std = [ 1., 1., 1. ])])

    invTrans = gray_tfs if t_type == "gray" else rgb_tfs

    return (invTrans(t) * 255).detach().cpu().permute(1,2,0).numpy().astype(np.uint8) if inv_trans else (t * 255).detach().cpu().permute(1,2,0).numpy().astype(np.uint8)

def visualize(data, n_ims, rows, cmap = None):

    assert cmap in ["rgb", "gray"], "Specify whether the image is black and white or color"
    if cmap == "rgb": cmap = "green"

    plt.figure(figsize = (20, 10))
    indekslar = [random.randint(0, len(data) - 1) for _ in range(n_ims)]
    for idx, indeks in enumerate(indekslar):
        im, target = data[indeks]
        img = tensor_2_im(im, inv_trans = True)
        bbox_class_names = []
        for i, cntr in enumerate(target["boxes"]):
            r, g, b = [random.randint(0, 255) for _ in range(3)]
            x, y, w, h = [round(c.item()) for c in cntr]
            bbox_class_names.append(list(class_names.keys())[target["labels"][i].item()])
            cv2.rectangle(img = img, pt1 = (x, y), pt2 = (w, h), color = (r, g, b), thickness = 2)
        bbox_class_names = [bbox_class_name for bbox_class_name in bbox_class_names]
        plt.subplot(rows, n_ims // rows, idx + 1)

        plt.imshow(img); plt.title(f"{bbox_class_names}")

        plt.axis("off")

visualize(tr_dl.dataset, 20, 4, "rgb")

# %% [markdown]
# ### AI Model

# %%
from torchvision.models.detection import fasterrcnn_resnet50_fpn

m = fasterrcnn_resnet50_fpn(weights = "DEFAULT")
device, num_classes = "cuda", len(class_names)

# get number of input features for the classifier
in_features = m.roi_heads.box_predictor.cls_score.in_features
# replace the pre-trained head with a new one
m.roi_heads.box_predictor.cls_score = torch.nn.Linear(in_features, num_classes)
m.roi_heads.box_predictor.bbox_pred = torch.nn.Linear(in_features, num_classes * 4)
m.to(device)
optimizer = torch.optim.SGD(m.parameters(), lr = 0.001, momentum = 0.9, weight_decay = 0.0005)
# and a learning rate scheduler
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size = 3, gamma = 0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100%|██████████| 160M/160M [00:01<00:00, 151MB/s]

# %% [markdown]
# ### Evaluation Metrics

# %%
# !pip install pycocotools
import torch.distributed as dist, datetime
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval
import pycocotools.mask as mask_util
from contextlib import redirect_stdout
import copy, io

class CocoEvaluator:
    def __init__(self, coco_gt, iou_types):
        if not isinstance(iou_types, (list, tuple)):
            raise TypeError(f"This constructor expects iou_types of type list or tuple, instead  got {type(iou_types)}")
        coco_gt = copy.deepcopy(coco_gt)
        self.coco_gt = coco_gt

        self.iou_types = iou_types
        self.coco_eval = {}
        for iou_type in iou_types:
            self.coco_eval[iou_type] = COCOeval(coco_gt, iouType=iou_type)

        self.img_ids = []
        self.eval_imgs = {k: [] for k in iou_types}

    def update(self, predictions):
        img_ids = list(np.unique(list(predictions.keys())))
        self.img_ids.extend(img_ids)

        for iou_type in self.iou_types:
            results = self.prepare(predictions, iou_type)
            with redirect_stdout(io.StringIO()):
                coco_dt = COCO.loadRes(self.coco_gt, results) if results else COCO()
            coco_eval = self.coco_eval[iou_type]

            coco_eval.cocoDt = coco_dt
            coco_eval.params.imgIds = list(img_ids)
            img_ids, eval_imgs = evaluate_coco(coco_eval)

            self.eval_imgs[iou_type].append(eval_imgs)

    def synchronize_between_processes(self):
        for iou_type in self.iou_types:
            self.eval_imgs[iou_type] = np.concatenate(self.eval_imgs[iou_type], 2)
            create_common_coco_eval(self.coco_eval[iou_type], self.img_ids, self.eval_imgs[iou_type])

    def accumulate(self):
        for coco_eval in self.coco_eval.values():
            coco_eval.accumulate()

    def summarize(self):
        for iou_type, coco_eval in self.coco_eval.items():
            print(f"IoU metric: {iou_type}")
            coco_eval.summarize()

    def prepare(self, predictions, iou_type):
        if iou_type == "bbox":
            return self.prepare_for_coco_detection(predictions)
        if iou_type == "segm":
            return self.prepare_for_coco_segmentation(predictions)
        if iou_type == "keypoints":
            return self.prepare_for_coco_keypoint(predictions)
        raise ValueError(f"Unknown iou type {iou_type}")

    def prepare_for_coco_detection(self, predictions):
        coco_results = []
        for original_id, prediction in predictions.items():
            if len(prediction) == 0:
                continue

            boxes = prediction["boxes"]
            boxes = convert_to_xywh(boxes).tolist()
            scores = prediction["scores"].tolist()
            labels = prediction["labels"].tolist()

            coco_results.extend(
                [
                    {
                        "image_id": original_id,
                        "category_id": labels[k],
                        "bbox": box,
                        "score": scores[k],
                    }
                    for k, box in enumerate(boxes)
                ]
            )
        return coco_results

    def prepare_for_coco_segmentation(self, predictions):
        coco_results = []
        for original_id, prediction in predictions.items():
            if len(prediction) == 0:
                continue

            scores = prediction["scores"]
            labels = prediction["labels"]
            masks = prediction["masks"]

            masks = masks > 0.5

            scores = prediction["scores"].tolist()
            labels = prediction["labels"].tolist()

            rles = [
                mask_util.encode(np.array(mask[0, :, :, np.newaxis], dtype=np.uint8, order="F"))[0] for mask in masks
            ]
            for rle in rles:
                rle["counts"] = rle["counts"].decode("utf-8")

            coco_results.extend(
                [
                    {
                        "image_id": original_id,
                        "category_id": labels[k],
                        "segmentation": rle,
                        "score": scores[k],
                    }
                    for k, rle in enumerate(rles)
                ]
            )
        return coco_results

    def prepare_for_coco_keypoint(self, predictions):
        coco_results = []
        for original_id, prediction in predictions.items():
            if len(prediction) == 0:
                continue

            boxes = prediction["boxes"]
            boxes = convert_to_xywh(boxes).tolist()
            scores = prediction["scores"].tolist()
            labels = prediction["labels"].tolist()
            keypoints = prediction["keypoints"]
            keypoints = keypoints.flatten(start_dim=1).tolist()

            coco_results.extend(
                [
                    {
                        "image_id": original_id,
                        "category_id": labels[k],
                        "keypoints": keypoint,
                        "score": scores[k],
                    }
                    for k, keypoint in enumerate(keypoints)
                ]
            )
        return coco_results


def convert_to_xywh(boxes):
    xmin, ymin, xmax, ymax = boxes.unbind(1)
    return torch.stack((xmin, ymin, xmax - xmin, ymax - ymin), dim=1)


def merge(img_ids, eval_imgs):
    all_img_ids = all_gather(img_ids)
    all_eval_imgs = all_gather(eval_imgs)

    merged_img_ids = []
    for p in all_img_ids:
        merged_img_ids.extend(p)

    merged_eval_imgs = []
    for p in all_eval_imgs:
        merged_eval_imgs.append(p)

    merged_img_ids = np.array(merged_img_ids)
    merged_eval_imgs = np.concatenate(merged_eval_imgs, 2)

    # keep only unique (and in sorted order) images
    merged_img_ids, idx = np.unique(merged_img_ids, return_index=True)
    merged_eval_imgs = merged_eval_imgs[..., idx]

    return merged_img_ids, merged_eval_imgs


def create_common_coco_eval(coco_eval, img_ids, eval_imgs):
    img_ids, eval_imgs = merge(img_ids, eval_imgs)
    img_ids = list(img_ids)
    eval_imgs = list(eval_imgs.flatten())

    coco_eval.evalImgs = eval_imgs
    coco_eval.params.imgIds = img_ids
    coco_eval._paramsEval = copy.deepcopy(coco_eval.params)


def evaluate_coco(imgs):
    with redirect_stdout(io.StringIO()):
        imgs.evaluate()
    return imgs.params.imgIds, np.asarray(imgs.evalImgs).reshape(-1, len(imgs.params.areaRng), len(imgs.params.imgIds))


def all_gather(data):
    """
    Run all_gather on arbitrary picklable data (not necessarily tensors)
    Args:
        data: any picklable object
    Returns:
        list[data]: list of data gathered from each rank
    """
    world_size = get_world_size()
    if world_size == 1:
        return [data]
    data_list = [None] * world_size
    dist.all_gather_object(data_list, data)
    return data_list
# Out:
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (2.0.8)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pycocotools) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.16.0)

# %%
import math, sys, time, torch, torchvision
import torchvision.models.detection.mask_rcnn
from pycocotools.coco import COCO
from pycocotools import mask as coco_mask
from collections import defaultdict, deque

def convert_to_coco_api(ds):
    coco_ds = COCO()
    # annotation IDs need to start at 1, not 0, see torchvision issue #1530
    ann_id = 1
    dataset = {"images": [], "categories": [], "annotations": []}
    categories = set()
    for img_idx in range(len(ds)):
        # find better way to get target
        # targets = ds.get_annotations(img_idx)
        img, targets = ds[img_idx]
        image_id = targets["image_id"].item()
        img_dict = {}
        img_dict["id"] = image_id
        img_dict["height"] = img.shape[-2]
        img_dict["width"] = img.shape[-1]
        dataset["images"].append(img_dict)
        bboxes = targets["boxes"].clone()
        bboxes[:, 2:] -= bboxes[:, :2]
        bboxes = bboxes.tolist()
        labels = targets["labels"].tolist()
        areas = targets["area"].tolist()
        iscrowd = targets["iscrowd"].tolist()
        if "masks" in targets:
            masks = targets["masks"]
            # make masks Fortran contiguous for coco_mask
            masks = masks.permute(0, 2, 1).contiguous().permute(0, 2, 1)
        if "keypoints" in targets:
            keypoints = targets["keypoints"]
            keypoints = keypoints.reshape(keypoints.shape[0], -1).tolist()
        num_objs = len(bboxes)
        for i in range(num_objs):
            ann = {}
            ann["image_id"] = image_id
            ann["bbox"] = bboxes[i]
            ann["category_id"] = labels[i]
            categories.add(labels[i])
            ann["area"] = areas[i]
            ann["iscrowd"] = iscrowd[i]
            ann["id"] = ann_id
            if "masks" in targets:
                ann["segmentation"] = coco_mask.encode(masks[i].numpy())
            if "keypoints" in targets:
                ann["keypoints"] = keypoints[i]
                ann["num_keypoints"] = sum(k != 0 for k in keypoints[i][2::3])
            dataset["annotations"].append(ann)
            ann_id += 1
    dataset["categories"] = [{"id": i} for i in sorted(categories)]
    coco_ds.dataset = dataset
    coco_ds.createIndex()
    return coco_ds

def get_coco_api_from_dataset(dataset):
    for _ in range(10):
        if isinstance(dataset, torchvision.datasets.CocoDetection):
            break
        if isinstance(dataset, torch.utils.data.Subset):
            dataset = dataset.dataset
    if isinstance(dataset, torchvision.datasets.CocoDetection):
        return dataset.coco
    return convert_to_coco_api(dataset)

def train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq, scaler = None):
    model.train()
    metric_logger = MetricLogger(delimiter=" | ")
    metric_logger.add_meter("lr", SmoothedValue(window_size=1, fmt="{value:.6f}"))
    header = f"{epoch + 1}-epoch number "

    lr_scheduler = None
    if epoch == 0:
        warmup_factor = 1.0 / 1000
        warmup_iters = min(1000, len(data_loader) - 1)

        lr_scheduler = torch.optim.lr_scheduler.LinearLR(
            optimizer, start_factor=warmup_factor, total_iters=warmup_iters
        )

    for idx, (images, targets) in enumerate(metric_logger.log_every(data_loader, print_freq, header)):
        images = list(image.to(device) for image in images)

        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]  # change here

        # targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
        with torch.cuda.amp.autocast(enabled=scaler is not None):
            loss_dict = model(images, targets)
            losses = sum(loss for loss in loss_dict.values())

        # reduce losses over all GPUs for logging purposes
        loss_dict_reduced = reduce_dict(loss_dict)
        losses_reduced = sum(loss for loss in loss_dict_reduced.values())

        loss_value = losses_reduced.item()

        if not math.isfinite(loss_value):
            print(f"Loss {loss_value} as we stop the training process")
            print(loss_dict_reduced)
            sys.exit(1)

        optimizer.zero_grad()
        if scaler is not None:
            scaler.scale(losses).backward()
            scaler.step(optimizer)
            scaler.update()
        else:
            losses.backward()
            optimizer.step()

        if lr_scheduler is not None:
            lr_scheduler.step()

        metric_logger.update(loss=losses_reduced, **loss_dict_reduced)
        metric_logger.update(lr=optimizer.param_groups[0]["lr"])

    return metric_logger

def _get_iou_types(model):
    model_without_ddp = model
    if isinstance(model, torch.nn.parallel.DistributedDataParallel):
        model_without_ddp = model.module
    iou_types = ["bbox"]
    if isinstance(model_without_ddp, torchvision.models.detection.MaskRCNN):
        iou_types.append("segm")
    if isinstance(model_without_ddp, torchvision.models.detection.KeypointRCNN):
        iou_types.append("keypoints")
    return iou_types

# @torch.inference_mode()
def evaluate(model, data_loader, device):
    n_threads = torch.get_num_threads()
    # remove this and make paste_masks_in_image run on the GPU
    torch.set_num_threads(1)
    cpu_device = torch.device("cpu")
    model.eval()
    metric_logger = MetricLogger(delimiter=" | ")
    header = "Testing Process: "

    coco = get_coco_api_from_dataset(data_loader.dataset)
    iou_types = _get_iou_types(model)
    coco_evaluator = CocoEvaluator(coco, iou_types)

    for images, targets in metric_logger.log_every(data_loader, 100, header):

        images = list(img.to(device) for img in images)

        if torch.cuda.is_available(): torch.cuda.synchronize()
        model_time = time.time()
        outputs = model(images)

        outputs = [{k: v.to(cpu_device) for k, v in t.items()} for t in outputs]
        model_time = time.time() - model_time

        res = {target["image_id"].item(): output for target, output in zip(targets, outputs)}
        evaluator_time = time.time()
        coco_evaluator.update(res)
        evaluator_time = time.time() - evaluator_time
        metric_logger.update(model_time=model_time, eval_time=evaluator_time)

    # gather the stats from all processes
    metric_logger.synchronize_between_processes()
    print(f"\nTest Statistics: {metric_logger}\n")
    coco_evaluator.synchronize_between_processes()

    # accumulate predictions from all images
    coco_evaluator.accumulate()
    coco_evaluator.summarize()
    torch.set_num_threads(n_threads)

    return coco_evaluator

class SmoothedValue:
    """Track a series of values and provide access to smoothed values over a
    window or the global series average.
    """

    def __init__(self, window_size=20, fmt=None):
        if fmt is None:
            fmt = "{median:.4f} ({global_avg:.4f})"
        self.deque = deque(maxlen=window_size)
        self.total = 0.0
        self.count = 0
        self.fmt = fmt

    def update(self, value, n=1):
        self.deque.append(value)
        self.count += n
        self.total += value * n

    def synchronize_between_processes(self):
        """
        Warning: does not synchronize the deque!
        """
        if not is_dist_avail_and_initialized():
            return
        t = torch.tensor([self.count, self.total], dtype=torch.float64, device="cuda")
        dist.barrier()
        dist.all_reduce(t)
        t = t.tolist()
        self.count = int(t[0])
        self.total = t[1]

    @property
    def median(self):
        d = torch.tensor(list(self.deque))
        return d.median().item()

    @property
    def avg(self):
        d = torch.tensor(list(self.deque), dtype=torch.float32)
        return d.mean().item()

    @property
    def global_avg(self):
        return self.total / self.count

    @property
    def max(self):
        return max(self.deque)

    @property
    def value(self):
        return self.deque[-1]

    def __str__(self):
        return self.fmt.format(
            median=self.median, avg=self.avg, global_avg=self.global_avg, max=self.max, value=self.value
        )

class MetricLogger:
    def __init__(self, delimiter=" | "):
        self.meters = defaultdict(SmoothedValue)
        self.delimiter = delimiter

    def update(self, **kwargs):
        for k, v in kwargs.items():
            if isinstance(v, torch.Tensor):
                v = v.item()
            assert isinstance(v, (float, int))
            self.meters[k].update(v)

    def __getattr__(self, attr):
        if attr in self.meters:
            return self.meters[attr]
        if attr in self.__dict__:
            return self.__dict__[attr]
        raise AttributeError(f"'{type(self).__name__}' object has no attribute '{attr}'")

    def __str__(self):
        loss_str = []
        for name, meter in self.meters.items():
            loss_str.append(f"{name}: {str(meter)}")
        return self.delimiter.join(loss_str)

    def synchronize_between_processes(self):
        for meter in self.meters.values():
            meter.synchronize_between_processes()

    def add_meter(self, name, meter):
        self.meters[name] = meter

    def log_every(self, iterable, print_freq, header=None):
        i = 0
        if not header:
            header = ""
        start_time = time.time()
        end = time.time()
        iter_time = SmoothedValue(fmt="{avg:.4f}")
        data_time = SmoothedValue(fmt="{avg:.4f}")
        space_fmt = ":" + str(len(str(len(iterable)))) + "d"
        if torch.cuda.is_available():
            init_msg = "".join(
                [
                    f"\n{header}",
                    "{1}From Batch {0" + space_fmt +"}-Result: \n",
                ]
            )

            log_msg = self.delimiter.join(
                [
                    "{meters}",
                    "time -> {time}",
                ]
            )
        else:
            log_msg = self.delimiter.join(
                [header, "[{0" + space_fmt + "}/{1}]", "eta: {eta}", "{meters}", "time: {time}", "data: {data}"]
            )
        MB = 1024.0 * 1024.0
        for obj in iterable:
            data_time.update(time.time() - end)
            yield obj
            iter_time.update(time.time() - end)
            if i % print_freq == 0 or i == len(iterable) - 1:
                eta_seconds = iter_time.global_avg * (len(iterable) - i)
                eta_string = str(datetime.timedelta(seconds=int(eta_seconds)))
                if torch.cuda.is_available():
                    print(init_msg.format(i + 1, len(iterable)))
                    print(
                        log_msg.format(
                            meters=str(self),
                            time=str(iter_time),
                        )
                    )
                else:
                    print(
                        log_msg.format(
                            i, len(iterable), eta=eta_string, meters=str(self), time=str(iter_time), data=str(data_time)
                        )
                    )
            i += 1
            end = time.time()
        total_time = time.time() - start_time
        total_time_str = str(datetime.timedelta(seconds=int(total_time)))
        print(f"{header} total time: {total_time_str} ({total_time / len(iterable):.4f} s / picture)")

def reduce_dict(input_dict, average=True):

    world_size = get_world_size()
    if world_size < 2:
        return input_dict
    with torch.inference_mode():
        names = []
        values = []
        # sort the keys so that they are consistent across processes
        for k in sorted(input_dict.keys()):
            names.append(k)
            values.append(input_dict[k])
        values = torch.stack(values, dim=0)
        dist.all_reduce(values)
        if average:
            values /= world_size
        reduced_dict = {k: v for k, v in zip(names, values)}
    return reduced_dict

def get_world_size():
    if not is_dist_avail_and_initialized():
        return 1
    return dist.get_world_size()

def is_dist_avail_and_initialized():
    if not dist.is_available():
        return False
    if not dist.is_initialized():
        return False
    return True

# %% [markdown]
# ### Train and Validation

# %%
model_prefix = "road"
epochs = 10
save_model_path = "saved_models"
for epoch in range(epochs):
    # train for one epoch, printing every 10 iterations
    train_one_epoch(m, optimizer, tr_dl, device, epoch, print_freq = 10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(m, val_dl, device = device)

os.makedirs(f"{save_model_path}", exist_ok = True)
torch.save(m, f"{save_model_path}/{model_prefix}_best_model.pt")
print("Training Complete!")
# Out:
# 1-epoch number 176From Batch   1-Result:
#
# lr: 0.000007 | loss: 0.8202 (0.8202) | loss_classifier: 0.6510 (0.6510) | loss_box_reg: 0.0913 (0.0913) | loss_objectness: 0.0733 (0.0733) | loss_rpn_box_reg: 0.0047 (0.0047) | time -> 3.8381
#
# 1-epoch number 176From Batch  11-Result:
#
# lr: 0.000064 | loss: 0.6958 (0.6897) | loss_classifier: 0.5421 (0.5288) | loss_box_reg: 0.1035 (0.0954) | loss_objectness: 0.0558 (0.0585) | loss_rpn_box_reg: 0.0071 (0.0069) | time -> 1.3619
#
# 1-epoch number 176From Batch  21-Result:
#
# lr: 0.000121 | loss: 0.4409 (0.5274) | loss_classifier: 0.3368 (0.3737) | loss_box_reg: 0.1123 (0.1066) | loss_objectness: 0.0319 (0.0406) | loss_rpn_box_reg: 0.0061 (0.0064) | time -> 1.1725
#
# 1-epoch number 176From Batch  31-Result:
#
# lr: 0.000178 | loss: 0.3144 (0.4735) | loss_classifier: 0.1684 (0.3118) | loss_box_reg: 0.1230 (0.1116) | loss_objectness: 0.0188 (0.0434) | loss_rpn_box_reg: 0.0044 (0.0066) | time -> 1.1826
#
# 1-epoch number 176From Batch  41-Result:
#
# lr: 0.000235 | loss: 0.3144 (0.4374) | loss_classifier: 0.1647 (0.2816) | loss_box_reg: 0.1090 (0.1114) | loss_objectness: 0.0188 (0.0379) | loss_rpn_box_reg: 0.0053 (0.0065) | time -> 1.1473
#
# 1-epoch number 176From Batch  51-Result:
#
# lr: 0.000292 | loss: 0.2746 (0.4089) | loss_classifier: 0.1466 (0.2558) | loss_box_reg: 0.1038 (0.1128) | loss_objectness: 0.0200 (0.0341) | loss_rpn_box_reg: 0.0048 (0.0061) | time -> 1.1854
#
# 1-epoch number 176From Batch  61-Result:
#
# lr: 0.000349 | loss: 0.2928 (0.3917) | loss_classifier: 0.1435 (0.2379) | loss_box_reg: 0.1348 (0.1172) | loss_objectness: 0.0138 (0.0307) | loss_rpn_box_reg: 0.0036 (0.0060) | time -> 1.1691
#
# 1-epoch number 176From Batch  71-Result:
#
# lr: 0.000406 | loss: 0.2565 (0.3890) | loss_classifier: 0.1182 (0.2181) | loss_box_reg: 0.1172 (0.1164) | loss_objectness: 0.0099 (0.0479) | loss_rpn_box_reg: 0.0033 (0.0067) | time -> 1.1725
#
# 1-epoch number 176From Batch  81-Result:
#
# lr: 0.000463 | loss: 0.2503 (0.3747) | loss_classifier: 0.0954 (0.2057) | loss_box_reg: 0.1145 (0.1174) | loss_objectness: 0.0086 (0.0452) | loss_rpn_box_reg: 0.0027 (0.0064) | time -> 1.2283
#
# 1-epoch number 176From Batch  91-Result:
#
# lr: 0.000520 | loss: 0.2579 (0.3621) | loss_classifier: 0.0929 (0.1936) | loss_box_reg: 0.1214 (0.1176) | loss_objectness: 0.0069 (0.0444) | loss_rpn_box_reg: 0.0034 (0.0066) | time -> 1.1865
#
# 1-epoch number 176From Batch 101-Result:
#
# lr: 0.000578 | loss: 0.2337 (0.3458) | loss_classifier: 0.0870 (0.1820) | loss_box_reg: 0.1136 (0.1166) | loss_objectness: 0.0073 (0.0410) | loss_rpn_box_reg: 0.0029 (0.0062) | time -> 1.1193
#
# 1-epoch number 176From Batch 111-Result:
#
# lr: 0.000635 | loss: 0.1810 (0.3313) | loss_classifier: 0.0589 (0.1711) | loss_box_reg: 0.0978 (0.1156) | loss_objectness: 0.0073 (0.0386) | loss_rpn_box_reg: 0.0023 (0.0059) | time -> 1.0939
#
# 1-epoch number 176From Batch 121-Result:
#
# lr: 0.000692 | loss: 0.1728 (0.3208) | loss_classifier: 0.0551 (0.1634) | loss_box_reg: 0.0885 (0.1142) | loss_objectness: 0.0061 (0.0374) | loss_rpn_box_reg: 0.0024 (0.0058) | time -> 1.0503
#
# 1-epoch number 176From Batch 131-Result:
#
# lr: 0.000749 | loss: 0.1755 (0.3087) | loss_classifier: 0.0711 (0.1560) | loss_box_reg: 0.0885 (0.1119) | loss_objectness: 0.0067 (0.0353) | loss_rpn_box_reg: 0.0029 (0.0056) | time -> 1.0773
#
# 1-epoch number 176From Batch 141-Result:
#
# lr: 0.000806 | loss: 0.1518 (0.2972) | loss_classifier: 0.0596 (0.1492) | loss_box_reg: 0.0777 (0.1094) | loss_objectness: 0.0062 (0.0332) | loss_rpn_box_reg: 0.0028 (0.0055) | time -> 1.1478
#
# 1-epoch number 176From Batch 151-Result:
#
# lr: 0.000863 | loss: 0.1332 (0.2885) | loss_classifier: 0.0571 (0.1440) | loss_box_reg: 0.0716 (0.1077) | loss_objectness: 0.0055 (0.0315) | loss_rpn_box_reg: 0.0033 (0.0053) | time -> 1.1483
#
# 1-epoch number 176From Batch 161-Result:
#
# lr: 0.000920 | loss: 0.1436 (0.2790) | loss_classifier: 0.0537 (0.1386) | loss_box_reg: 0.0670 (0.1049) | loss_objectness: 0.0054 (0.0303) | loss_rpn_box_reg: 0.0023 (0.0052) | time -> 1.1840
#
# 1-epoch number 176From Batch 171-Result:
#
# lr: 0.000977 | loss: 0.1338 (0.2692) | loss_classifier: 0.0442 (0.1331) | loss_box_reg: 0.0521 (0.1021) | loss_objectness: 0.0030 (0.0290) | loss_rpn_box_reg: 0.0023 (0.0051) | time -> 1.2558
#
# 1-epoch number 176From Batch 176-Result:
#
# lr: 0.001000 | loss: 0.1089 (0.2649) | loss_classifier: 0.0418 (0.1307) | loss_box_reg: 0.0521 (0.1009) | loss_objectness: 0.0023 (0.0283) | loss_rpn_box_reg: 0.0016 (0.0050) | time -> 1.1710
# 1-epoch number  total time: 0:03:25 (1.1665 s / picture)
# creating index...
# index created!
#
# Testing Process: 22From Batch  1-Result:
#
# model_time: 0.6530 (0.6530) | eval_time: 0.0090 (0.0090) | time -> 0.9106
#
# Testing Process: 22From Batch 22-Result:
#
# model_time: 0.4311 (0.5173) | eval_time: 0.0050 (0.0056) | time -> 0.5375
# Testing Process:  total time: 0:00:12 (0.5552 s / picture)
#
# Test Statistics: model_time: 0.4311 (0.5173) | eval_time: 0.0050 (0.0056)
#
# Accumulating evaluation results...
# DONE (t=0.10s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.293
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.461
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.327
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.291
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.326
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.432
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.348
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.428
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.428
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.383
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.452
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.552
#
# 2-epoch number 176From Batch   1-Result:
#
# lr: 0.001000 | loss: 0.0772 (0.0772) | loss_classifier: 0.0236 (0.0236) | loss_box_reg: 0.0507 (0.0507) | loss_objectness: 0.0019 (0.0019) | loss_rpn_box_reg: 0.0010 (0.0010) | time -> 1.3870
#
# 2-epoch number 176From Batch  11-Result:
#
# lr: 0.001000 | loss: 0.0960 (0.1130) | loss_classifier: 0.0405 (0.0470) | loss_box_reg: 0.0520 (0.0592) | loss_objectness: 0.0025 (0.0046) | loss_rpn_box_reg: 0.0012 (0.0022) | time -> 1.1157
#
# 2-epoch number 176From Batch  21-Result:
#
# lr: 0.001000 | loss: 0.0968 (0.1130) | loss_classifier: 0.0415 (0.0463) | loss_box_reg: 0.0520 (0.0586) | loss_objectness: 0.0023 (0.0057) | loss_rpn_box_reg: 0.0019 (0.0024) | time -> 1.1207
#
# 2-epoch number 176From Batch  31-Result:
#
# lr: 0.001000 | loss: 0.0968 (0.1142) | loss_classifier: 0.0415 (0.0460) | loss_box_reg: 0.0568 (0.0601) | loss_objectness: 0.0018 (0.0057) | loss_rpn_box_reg: 0.0020 (0.0024) | time -> 1.1644
#
# 2-epoch number 176From Batch  41-Result:
#
# lr: 0.001000 | loss: 0.0901 (0.1118) | loss_classifier: 0.0370 (0.0449) | loss_box_reg: 0.0533 (0.0599) | loss_objectness: 0.0016 (0.0048) | loss_rpn_box_reg: 0.0016 (0.0022) | time -> 1.1752
#
# 2-epoch number 176From Batch  51-Result:
#
# lr: 0.001000 | loss: 0.1013 (0.1145) | loss_classifier: 0.0443 (0.0455) | loss_box_reg: 0.0559 (0.0613) | loss_objectness: 0.0022 (0.0055) | loss_rpn_box_reg: 0.0011 (0.0023) | time -> 1.1190
#
# 2-epoch number 176From Batch  61-Result:
#
# lr: 0.001000 | loss: 0.1126 (0.1143) | loss_classifier: 0.0483 (0.0451) | loss_box_reg: 0.0607 (0.0611) | loss_objectness: 0.0030 (0.0056) | loss_rpn_box_reg: 0.0013 (0.0025) | time -> 1.0770
#
# 2-epoch number 176From Batch  71-Result:
#
# lr: 0.001000 | loss: 0.0875 (0.1118) | loss_classifier: 0.0374 (0.0439) | loss_box_reg: 0.0494 (0.0603) | loss_objectness: 0.0019 (0.0052) | loss_rpn_box_reg: 0.0020 (0.0024) | time -> 1.0736
#
# 2-epoch number 176From Batch  81-Result:
#
# lr: 0.001000 | loss: 0.0875 (0.1104) | loss_classifier: 0.0374 (0.0438) | loss_box_reg: 0.0473 (0.0593) | loss_objectness: 0.0008 (0.0050) | loss_rpn_box_reg: 0.0012 (0.0023) | time -> 1.1273
#
# 2-epoch number 176From Batch  91-Result:
#
# lr: 0.001000 | loss: 0.0796 (0.1106) | loss_classifier: 0.0290 (0.0425) | loss_box_reg: 0.0388 (0.0573) | loss_objectness: 0.0021 (0.0079) | loss_rpn_box_reg: 0.0011 (0.0028) | time -> 1.1232
#
# 2-epoch number 176From Batch 101-Result:
#
# lr: 0.001000 | loss: 0.0824 (0.1105) | loss_classifier: 0.0290 (0.0426) | loss_box_reg: 0.0394 (0.0568) | loss_objectness: 0.0055 (0.0083) | loss_rpn_box_reg: 0.0018 (0.0029) | time -> 1.0523
#
# 2-epoch number 176From Batch 111-Result:
#
# lr: 0.001000 | loss: 0.0952 (0.1095) | loss_classifier: 0.0350 (0.0419) | loss_box_reg: 0.0503 (0.0567) | loss_objectness: 0.0042 (0.0081) | loss_rpn_box_reg: 0.0018 (0.0028) | time -> 1.1248
#
# 2-epoch number 176From Batch 121-Result:
#
# lr: 0.001000 | loss: 0.0895 (0.1073) | loss_classifier: 0.0289 (0.0407) | loss_box_reg: 0.0462 (0.0556) | loss_objectness: 0.0017 (0.0081) | loss_rpn_box_reg: 0.0014 (0.0028) | time -> 1.1848
#
# 2-epoch number 176From Batch 131-Result:
#
# lr: 0.001000 | loss: 0.0765 (0.1055) | loss_classifier: 0.0265 (0.0399) | loss_box_reg: 0.0346 (0.0547) | loss_objectness: 0.0020 (0.0080) | loss_rpn_box_reg: 0.0016 (0.0029) | time -> 1.1704
#
# 2-epoch number 176From Batch 141-Result:
#
# lr: 0.001000 | loss: 0.0744 (0.1033) | loss_classifier: 0.0263 (0.0390) | loss_box_reg: 0.0406 (0.0540) | loss_objectness: 0.0015 (0.0076) | loss_rpn_box_reg: 0.0014 (0.0028) | time -> 1.1767
#
# 2-epoch number 176From Batch 151-Result:
#
# lr: 0.001000 | loss: 0.0707 (0.1022) | loss_classifier: 0.0256 (0.0388) | loss_box_reg: 0.0406 (0.0534) | loss_objectness: 0.0012 (0.0073) | loss_rpn_box_reg: 0.0010 (0.0027) | time -> 1.1789
#
# 2-epoch number 176From Batch 161-Result:
#
# lr: 0.001000 | loss: 0.0686 (0.1006) | loss_classifier: 0.0234 (0.0381) | loss_box_reg: 0.0416 (0.0526) | loss_objectness: 0.0012 (0.0072) | loss_rpn_box_reg: 0.0017 (0.0027) | time -> 1.1777
#
# 2-epoch number 176From Batch 171-Result:
#
# lr: 0.001000 | loss: 0.0622 (0.0988) | loss_classifier: 0.0217 (0.0373) | loss_box_reg: 0.0392 (0.0515) | loss_objectness: 0.0017 (0.0072) | loss_rpn_box_reg: 0.0017 (0.0027) | time -> 1.1307
#
# 2-epoch number 176From Batch 176-Result:
#
# lr: 0.001000 | loss: 0.0673 (0.0982) | loss_classifier: 0.0206 (0.0371) | loss_box_reg: 0.0392 (0.0514) | loss_objectness: 0.0020 (0.0070) | loss_rpn_box_reg: 0.0011 (0.0027) | time -> 1.1213
# 2-epoch number  total time: 0:03:19 (1.1309 s / picture)
# creating index...
# index created!
#
# Testing Process: 22From Batch  1-Result:
#
# model_time: 0.6397 (0.6397) | eval_time: 0.0051 (0.0051) | time -> 1.4130
#
# Testing Process: 22From Batch 22-Result:
#
# model_time: 0.4335 (0.5154) | eval_time: 0.0047 (0.0050) | time -> 0.5368
# Testing Process:  total time: 0:00:12 (0.5774 s / picture)
#
# Test Statistics: model_time: 0.4335 (0.5154) | eval_time: 0.0047 (0.0050)
#
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.473
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.677
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.488
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.435
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.456
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.723
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.480
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.532
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.532
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.452
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.525
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.776
#
# 3-epoch number 176From Batch   1-Result:
#
# lr: 0.001000 | loss: 0.0640 (0.0640) | loss_classifier: 0.0304 (0.0304) | loss_box_reg: 0.0320 (0.0320) | loss_objectness: 0.0007 (0.0007) | loss_rpn_box_reg: 0.0009 (0.0009) | time -> 1.3326
#
# 3-epoch number 176From Batch  11-Result:
#
# lr: 0.001000 | loss: 0.0727 (0.0738) | loss_classifier: 0.0272 (0.0260) | loss_box_reg: 0.0452 (0.0420) | loss_objectness: 0.0011 (0.0023) | loss_rpn_box_reg: 0.0020 (0.0035) | time -> 1.2024
#
# 3-epoch number 176From Batch  21-Result:
#
# lr: 0.001000 | loss: 0.0682 (0.0707) | loss_classifier: 0.0236 (0.0253) | loss_box_reg: 0.0428 (0.0409) | loss_objectness: 0.0011 (0.0018) | loss_rpn_box_reg: 0.0019 (0.0027) | time -> 1.1754
#
# 3-epoch number 176From Batch  31-Result:
#
# lr: 0.001000 | loss: 0.0599 (0.0685) | loss_classifier: 0.0205 (0.0240) | loss_box_reg: 0.0363 (0.0398) | loss_objectness: 0.0011 (0.0018) | loss_rpn_box_reg: 0.0014 (0.0028) | time -> 1.1203
#
# 3-epoch number 176From Batch  41-Result:
#
# lr: 0.001000 | loss: 0.0547 (0.0654) | loss_classifier: 0.0144 (0.0227) | loss_box_reg: 0.0363 (0.0384) | loss_objectness: 0.0010 (0.0018) | loss_rpn_box_reg: 0.0014 (0.0025) | time -> 1.1674
#
# 3-epoch number 176From Batch  51-Result:
#
# lr: 0.001000 | loss: 0.0550 (0.0667) | loss_classifier: 0.0166 (0.0231) | loss_box_reg: 0.0386 (0.0393) | loss_objectness: 0.0010 (0.0019) | loss_rpn_box_reg: 0.0010 (0.0024) | time -> 1.2229
#
# 3-epoch number 176From Batch  61-Result:
#
# lr: 0.001000 | loss: 0.0577 (0.0658) | loss_classifier: 0.0182 (0.0226) | loss_box_reg: 0.0382 (0.0389) | loss_objectness: 0.0010 (0.0020) | loss_rpn_box_reg: 0.0012 (0.0023) | time -> 1.1644
#
# 3-epoch number 176From Batch  71-Result:
#
# lr: 0.001000 | loss: 0.0615 (0.0662) | loss_classifier: 0.0206 (0.0224) | loss_box_reg: 0.0381 (0.0396) | loss_objectness: 0.0007 (0.0018) | loss_rpn_box_reg: 0.0012 (0.0023) | time -> 1.1034
#
# 3-epoch number 176From Batch  81-Result:
#
# lr: 0.001000 | loss: 0.0553 (0.0646) | loss_classifier: 0.0168 (0.0216) | loss_box_reg: 0.0374 (0.0390) | loss_objectness: 0.0006 (0.0019) | loss_rpn_box_reg: 0.0010 (0.0022) | time -> 1.0849
#
# 3-epoch number 176From Batch  91-Result:
#
# lr: 0.001000 | loss: 0.0536 (0.0648) | loss_classifier: 0.0168 (0.0221) | loss_box_reg: 0.0322 (0.0386) | loss_objectness: 0.0006 (0.0018) | loss_rpn_box_reg: 0.0008 (0.0023) | time -> 1.0976
#
# 3-epoch number 176From Batch 101-Result:
#
# lr: 0.001000 | loss: 0.0568 (0.0640) | loss_classifier: 0.0191 (0.0217) | loss_box_reg: 0.0350 (0.0384) | loss_objectness: 0.0005 (0.0017) | loss_rpn_box_reg: 0.0007 (0.0022) | time -> 1.1125
#
# 3-epoch number 176From Batch 111-Result:
#
# lr: 0.001000 | loss: 0.0599 (0.0655) | loss_classifier: 0.0189 (0.0220) | loss_box_reg: 0.0389 (0.0395) | loss_objectness: 0.0006 (0.0018) | loss_rpn_box_reg: 0.0011 (0.0022) | time -> 1.1362
#
# 3-epoch number 176From Batch 121-Result:
#
# lr: 0.001000 | loss: 0.0714 (0.0664) | loss_classifier: 0.0197 (0.0222) | loss_box_reg: 0.0439 (0.0400) | loss_objectness: 0.0010 (0.0020) | loss_rpn_box_reg: 0.0017 (0.0023) | time -> 1.1540
#
# 3-epoch number 176From Batch 131-Result:
#
# lr: 0.001000 | loss: 0.0576 (0.0648) | loss_classifier: 0.0164 (0.0216) | loss_box_reg: 0.0346 (0.0391) | loss_objectness: 0.0009 (0.0019) | loss_rpn_box_reg: 0.0013 (0.0022) | time -> 1.1235
#
# 3-epoch number 176From Batch 141-Result:
#
# lr: 0.001000 | loss: 0.0482 (0.0639) | loss_classifier: 0.0149 (0.0212) | loss_box_reg: 0.0316 (0.0386) | loss_objectness: 0.0009 (0.0020) | loss_rpn_box_reg: 0.0012 (0.0022) | time -> 1.1223
#
# 3-epoch number 176From Batch 151-Result:
#
# lr: 0.001000 | loss: 0.0503 (0.0644) | loss_classifier: 0.0155 (0.0212) | loss_box_reg: 0.0326 (0.0389) | loss_objectness: 0.0014 (0.0021) | loss_rpn_box_reg: 0.0012 (0.0021) | time -> 1.1622
#
# 3-epoch number 176From Batch 161-Result:
#
# lr: 0.001000 | loss: 0.0533 (0.0639) | loss_classifier: 0.0160 (0.0210) | loss_box_reg: 0.0338 (0.0387) | loss_objectness: 0.0006 (0.0021) | loss_rpn_box_reg: 0.0010 (0.0021) | time -> 1.1393
#
# 3-epoch number 176From Batch 171-Result:
#
# lr: 0.001000 | loss: 0.0533 (0.0639) | loss_classifier: 0.0160 (0.0210) | loss_box_reg: 0.0324 (0.0388) | loss_objectness: 0.0006 (0.0020) | loss_rpn_box_reg: 0.0012 (0.0021) | time -> 1.2069
#
# 3-epoch number 176From Batch 176-Result:
#
# lr: 0.001000 | loss: 0.0468 (0.0630) | loss_classifier: 0.0148 (0.0207) | loss_box_reg: 0.0257 (0.0382) | loss_objectness: 0.0002 (0.0020) | loss_rpn_box_reg: 0.0010 (0.0021) | time -> 1.2182
# 3-epoch number  total time: 0:03:22 (1.1495 s / picture)
# creating index...
# index created!
#
# Testing Process: 22From Batch  1-Result:
#
# model_time: 0.6636 (0.6636) | eval_time: 0.0043 (0.0043) | time -> 1.0458
#
# Testing Process: 22From Batch 22-Result:
#
# model_time: 0.4350 (0.5187) | eval_time: 0.0036 (0.0041) | time -> 0.5395
# Testing Process:  total time: 0:00:12 (0.5615 s / picture)
#
# Test Statistics: model_time: 0.4350 (0.5187) | eval_time: 0.0036 (0.0041)
#
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.539
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.711
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.585
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.483
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.545
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.720
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.524
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.575
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.575
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.503
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.579
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.776
#
# 4-epoch number 176From Batch   1-Result:
#
# lr: 0.000100 | loss: 0.0703 (0.0703) | loss_classifier: 0.0219 (0.0219) | loss_box_reg: 0.0464 (0.0464) | loss_objectness: 0.0004 (0.0004) | loss_rpn_box_reg: 0.0017 (0.0017) | time -> 1.3659
#
# 4-epoch number 176From Batch  11-Result:
#
# lr: 0.000100 | loss: 0.0608 (0.0702) | loss_classifier: 0.0190 (0.0217) | loss_box_reg: 0.0362 (0.0436) | loss_objectness: 0.0004 (0.0028) | loss_rpn_box_reg: 0.0017 (0.0021) | time -> 1.2971
#
# 4-epoch number 176From Batch  21-Result:
#
# lr: 0.000100 | loss: 0.0492 (0.0610) | loss_classifier: 0.0157 (0.0199) | loss_box_reg: 0.0332 (0.0377) | loss_objectness: 0.0003 (0.0017) | loss_rpn_box_reg: 0.0010 (0.0017) | time -> 1.2380
#
# 4-epoch number 176From Batch  31-Result:
#
# lr: 0.000100 | loss: 0.0432 (0.0571) | loss_classifier: 0.0156 (0.0190) | loss_box_reg: 0.0264 (0.0351) | loss_objectness: 0.0002 (0.0015) | loss_rpn_box_reg: 0.0011 (0.0016) | time -> 1.1528
#
# 4-epoch number 176From Batch  41-Result:
#
# lr: 0.000100 | loss: 0.0465 (0.0553) | loss_classifier: 0.0154 (0.0187) | loss_box_reg: 0.0300 (0.0339) | loss_objectness: 0.0002 (0.0013) | loss_rpn_box_reg: 0.0008 (0.0014) | time -> 1.1781
#
# 4-epoch number 176From Batch  51-Result:
#
# lr: 0.000100 | loss: 0.0490 (0.0551) | loss_classifier: 0.0159 (0.0184) | loss_box_reg: 0.0305 (0.0335) | loss_objectness: 0.0006 (0.0014) | loss_rpn_box_reg: 0.0011 (0.0017) | time -> 1.2323
#
# 4-epoch number 176From Batch  61-Result:
#
# lr: 0.000100 | loss: 0.0455 (0.0543) | loss_classifier: 0.0145 (0.0181) | loss_box_reg: 0.0311 (0.0331) | loss_objectness: 0.0006 (0.0014) | loss_rpn_box_reg: 0.0016 (0.0017) | time -> 1.1399
#
# 4-epoch number 176From Batch  71-Result:
#
# lr: 0.000100 | loss: 0.0455 (0.0560) | loss_classifier: 0.0145 (0.0191) | loss_box_reg: 0.0280 (0.0334) | loss_objectness: 0.0006 (0.0017) | loss_rpn_box_reg: 0.0009 (0.0019) | time -> 1.0680
#
# 4-epoch number 176From Batch  81-Result:
#
# lr: 0.000100 | loss: 0.0454 (0.0546) | loss_classifier: 0.0150 (0.0186) | loss_box_reg: 0.0277 (0.0326) | loss_objectness: 0.0008 (0.0016) | loss_rpn_box_reg: 0.0009 (0.0018) | time -> 1.0909
#
# 4-epoch number 176From Batch  91-Result:
#
# lr: 0.000100 | loss: 0.0389 (0.0524) | loss_classifier: 0.0131 (0.0179) | loss_box_reg: 0.0235 (0.0313) | loss_objectness: 0.0001 (0.0015) | loss_rpn_box_reg: 0.0011 (0.0018) | time -> 1.1053
#
# 4-epoch number 176From Batch 101-Result:
#
# lr: 0.000100 | loss: 0.0405 (0.0524) | loss_classifier: 0.0158 (0.0178) | loss_box_reg: 0.0235 (0.0314) | loss_objectness: 0.0002 (0.0015) | loss_rpn_box_reg: 0.0008 (0.0017) | time -> 1.0963
#
# 4-epoch number 176From Batch 111-Result:
#
# lr: 0.000100 | loss: 0.0547 (0.0533) | loss_classifier: 0.0187 (0.0183) | loss_box_reg: 0.0271 (0.0316) | loss_objectness: 0.0009 (0.0016) | loss_rpn_box_reg: 0.0011 (0.0018) | time -> 1.1197
#
# 4-epoch number 176From Batch 121-Result:
#
# lr: 0.000100 | loss: 0.0547 (0.0534) | loss_classifier: 0.0192 (0.0183) | loss_box_reg: 0.0294 (0.0318) | loss_objectness: 0.0005 (0.0015) | loss_rpn_box_reg: 0.0011 (0.0018) | time -> 1.1227
#
# 4-epoch number 176From Batch 131-Result:
#
# lr: 0.000100 | loss: 0.0573 (0.0536) | loss_classifier: 0.0187 (0.0183) | loss_box_reg: 0.0340 (0.0321) | loss_objectness: 0.0001 (0.0014) | loss_rpn_box_reg: 0.0009 (0.0017) | time -> 1.1089
#
# 4-epoch number 176From Batch 141-Result:
#
# lr: 0.000100 | loss: 0.0554 (0.0534) | loss_classifier: 0.0172 (0.0183) | loss_box_reg: 0.0303 (0.0320) | loss_objectness: 0.0003 (0.0015) | loss_rpn_box_reg: 0.0009 (0.0017) | time -> 1.1386
#
# 4-epoch number 176From Batch 151-Result:
#
# lr: 0.000100 | loss: 0.0465 (0.0534) | loss_classifier: 0.0172 (0.0183) | loss_box_reg: 0.0276 (0.0320) | loss_objectness: 0.0004 (0.0014) | loss_rpn_box_reg: 0.0010 (0.0017) | time -> 1.1597
#
# 4-epoch number 176From Batch 161-Result:
#
# lr: 0.000100 | loss: 0.0454 (0.0531) | loss_classifier: 0.0168 (0.0182) | loss_box_reg: 0.0259 (0.0318) | loss_objectness: 0.0003 (0.0013) | loss_rpn_box_reg: 0.0011 (0.0017) | time -> 1.2084
#
# 4-epoch number 176From Batch 171-Result:
#
# lr: 0.000100 | loss: 0.0410 (0.0527) | loss_classifier: 0.0148 (0.0180) | loss_box_reg: 0.0250 (0.0317) | loss_objectness: 0.0002 (0.0013) | loss_rpn_box_reg: 0.0011 (0.0017) | time -> 1.1856
#
# 4-epoch number 176From Batch 176-Result:
#
# lr: 0.000100 | loss: 0.0402 (0.0528) | loss_classifier: 0.0137 (0.0180) | loss_box_reg: 0.0241 (0.0317) | loss_objectness: 0.0002 (0.0013) | loss_rpn_box_reg: 0.0011 (0.0017) | time -> 1.0943
# 4-epoch number  total time: 0:03:22 (1.1496 s / picture)
# creating index...
# index created!
#
# Testing Process: 22From Batch  1-Result:
#
# model_time: 0.6573 (0.6573) | eval_time: 0.0042 (0.0042) | time -> 0.9654
#
# Testing Process: 22From Batch 22-Result:
#
# model_time: 0.4344 (0.5173) | eval_time: 0.0036 (0.0041) | time -> 0.5384
# Testing Process:  total time: 0:00:12 (0.5570 s / picture)
#
# Test Statistics: model_time: 0.4344 (0.5173) | eval_time: 0.0036 (0.0041)
#
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.566
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.713
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.689
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.482
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.586
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.788
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.539
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.593
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.593
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.510
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.601
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.820
#
# 5-epoch number 176From Batch   1-Result:
#
# lr: 0.000100 | loss: 0.0317 (0.0317) | loss_classifier: 0.0084 (0.0084) | loss_box_reg: 0.0203 (0.0203) | loss_objectness: 0.0010 (0.0010) | loss_rpn_box_reg: 0.0020 (0.0020) | time -> 1.8209
#
# 5-epoch number 176From Batch  11-Result:
#
# lr: 0.000100 | loss: 0.0463 (0.0468) | loss_classifier: 0.0146 (0.0161) | loss_box_reg: 0.0261 (0.0291) | loss_objectness: 0.0001 (0.0006) | loss_rpn_box_reg: 0.0009 (0.0010) | time -> 1.1356
#
# 5-epoch number 176From Batch  21-Result:
#
# lr: 0.000100 | loss: 0.0463 (0.0468) | loss_classifier: 0.0146 (0.0154) | loss_box_reg: 0.0265 (0.0283) | loss_objectness: 0.0002 (0.0021) | loss_rpn_box_reg: 0.0008 (0.0010) | time -> 1.1583
#
# 5-epoch number 176From Batch  31-Result:
#
# lr: 0.000100 | loss: 0.0463 (0.0475) | loss_classifier: 0.0140 (0.0164) | loss_box_reg: 0.0275 (0.0285) | loss_objectness: 0.0002 (0.0015) | loss_rpn_box_reg: 0.0011 (0.0011) | time -> 1.1878
#
# 5-epoch number 176From Batch  41-Result:
#
# lr: 0.000100 | loss: 0.0463 (0.0465) | loss_classifier: 0.0133 (0.0159) | loss_box_reg: 0.0291 (0.0282) | loss_objectness: 0.0002 (0.0013) | loss_rpn_box_reg: 0.0009 (0.0011) | time -> 1.0867
#
# 5-epoch number 176From Batch  51-Result:
#
# lr: 0.000100 | loss: 0.0420 (0.0486) | loss_classifier: 0.0125 (0.0169) | loss_box_reg: 0.0261 (0.0288) | loss_objectness: 0.0002 (0.0015) | loss_rpn_box_reg: 0.0007 (0.0014) | time -> 1.0452
#
# 5-epoch number 176From Batch  61-Result:
#
# lr: 0.000100 | loss: 0.0303 (0.0471) | loss_classifier: 0.0115 (0.0165) | loss_box_reg: 0.0191 (0.0280) | loss_objectness: 0.0002 (0.0013) | loss_rpn_box_reg: 0.0009 (0.0014) | time -> 1.0860
#
# 5-epoch number 176From Batch  71-Result:
#
# lr: 0.000100 | loss: 0.0377 (0.0459) | loss_classifier: 0.0117 (0.0160) | loss_box_reg: 0.0205 (0.0273) | loss_objectness: 0.0004 (0.0012) | loss_rpn_box_reg: 0.0009 (0.0014) | time -> 1.1559
#
# 5-epoch number 176From Batch  81-Result:
#
# lr: 0.000100 | loss: 0.0450 (0.0463) | loss_classifier: 0.0141 (0.0159) | loss_box_reg: 0.0272 (0.0278) | loss_objectness: 0.0003 (0.0012) | loss_rpn_box_reg: 0.0009 (0.0014) | time -> 1.1423
#
# 5-epoch number 176From Batch  91-Result:
#
# lr: 0.000100 | loss: 0.0454 (0.0470) | loss_classifier: 0.0142 (0.0161) | loss_box_reg: 0.0297 (0.0283) | loss_objectness: 0.0003 (0.0012) | loss_rpn_box_reg: 0.0008 (0.0014) | time -> 1.1223
#
# 5-epoch number 176From Batch 101-Result:
#
# lr: 0.000100 | loss: 0.0479 (0.0483) | loss_classifier: 0.0155 (0.0164) | loss_box_reg: 0.0278 (0.0293) | loss_objectness: 0.0003 (0.0012) | loss_rpn_box_reg: 0.0008 (0.0014) | time -> 1.1450
#
# 5-epoch number 176From Batch 111-Result:
#
# lr: 0.000100 | loss: 0.0479 (0.0487) | loss_classifier: 0.0155 (0.0167) | loss_box_reg: 0.0278 (0.0296) | loss_objectness: 0.0002 (0.0011) | loss_rpn_box_reg: 0.0007 (0.0013) | time -> 1.1618
#
# 5-epoch number 176From Batch 121-Result:
#
# lr: 0.000100 | loss: 0.0420 (0.0485) | loss_classifier: 0.0143 (0.0166) | loss_box_reg: 0.0261 (0.0293) | loss_objectness: 0.0005 (0.0011) | loss_rpn_box_reg: 0.0010 (0.0015) | time -> 1.1565
#
# 5-epoch number 176From Batch 131-Result:
#
# lr: 0.000100 | loss: 0.0420 (0.0489) | loss_classifier: 0.0148 (0.0168) | loss_box_reg: 0.0259 (0.0296) | loss_objectness: 0.0004 (0.0010) | loss_rpn_box_reg: 0.0012 (0.0015) | time -> 1.1454
#
# 5-epoch number 176From Batch 141-Result:
#
# lr: 0.000100 | loss: 0.0420 (0.0502) | loss_classifier: 0.0169 (0.0171) | loss_box_reg: 0.0271 (0.0305) | loss_objectness: 0.0002 (0.0010) | loss_rpn_box_reg: 0.0013 (0.0016) | time -> 1.2291
#
# 5-epoch number 176From Batch 151-Result:
#
# lr: 0.000100 | loss: 0.0541 (0.0505) | loss_classifier: 0.0141 (0.0171) | loss_box_reg: 0.0342 (0.0307) | loss_objectness: 0.0004 (0.0011) | loss_rpn_box_reg: 0.0013 (0.0016) | time -> 1.2175
#
# 5-epoch number 176From Batch 161-Result:
#
# lr: 0.000100 | loss: 0.0385 (0.0498) | loss_classifier: 0.0125 (0.0168) | loss_box_reg: 0.0211 (0.0303) | loss_objectness: 0.0004 (0.0011) | loss_rpn_box_reg: 0.0011 (0.0017) | time -> 1.1325
#
# 5-epoch number 176From Batch 171-Result:
#
# lr: 0.000100 | loss: 0.0392 (0.0497) | loss_classifier: 0.0145 (0.0168) | loss_box_reg: 0.0212 (0.0302) | loss_objectness: 0.0004 (0.0011) | loss_rpn_box_reg: 0.0007 (0.0016) | time -> 1.1474
#
# 5-epoch number 176From Batch 176-Result:
#
# lr: 0.000100 | loss: 0.0441 (0.0504) | loss_classifier: 0.0158 (0.0173) | loss_box_reg: 0.0245 (0.0303) | loss_objectness: 0.0007 (0.0011) | loss_rpn_box_reg: 0.0008 (0.0017) | time -> 1.1391
# 5-epoch number  total time: 0:03:21 (1.1459 s / picture)
# creating index...
# index created!
#
# Testing Process: 22From Batch  1-Result:
#
# model_time: 0.6484 (0.6484) | eval_time: 0.0038 (0.0038) | time -> 0.8825
#
# Testing Process: 22From Batch 22-Result:
#
# model_time: 0.4317 (0.5171) | eval_time: 0.0032 (0.0040) | time -> 0.5386
# Testing Process:  total time: 0:00:12 (0.5539 s / picture)
#
# Test Statistics: model_time: 0.4317 (0.5171) | eval_time: 0.0032 (0.0040)
#
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.564
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.713
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.689
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.488
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.580
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.797
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.542
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.593
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.593
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.519
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.595
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.816
#
# 6-epoch number 176From Batch   1-Result:
#
# lr: 0.000100 | loss: 0.0296 (0.0296) | loss_classifier: 0.0077 (0.0077) | loss_box_reg: 0.0208 (0.0208) | loss_objectness: 0.0005 (0.0005) | loss_rpn_box_reg: 0.0006 (0.0006) | time -> 1.6395
#
# 6-epoch number 176From Batch  11-Result:
#
# lr: 0.000100 | loss: 0.0502 (0.0550) | loss_classifier: 0.0178 (0.0181) | loss_box_reg: 0.0306 (0.0346) | loss_objectness: 0.0001 (0.0004) | loss_rpn_box_reg: 0.0013 (0.0019) | time -> 1.2151
#
# 6-epoch number 176From Batch  21-Result:
#
# lr: 0.000100 | loss: 0.0488 (0.0544) | loss_classifier: 0.0166 (0.0183) | loss_box_reg: 0.0276 (0.0338) | loss_objectness: 0.0002 (0.0005) | loss_rpn_box_reg: 0.0016 (0.0018) | time -> 1.1509
#
# 6-epoch number 176From Batch  31-Result:
#
# lr: 0.000100 | loss: 0.0427 (0.0505) | loss_classifier: 0.0164 (0.0175) | loss_box_reg: 0.0244 (0.0310) | loss_objectness: 0.0003 (0.0005) | loss_rpn_box_reg: 0.0009 (0.0015) | time -> 1.1904
#
# 6-epoch number 176From Batch  41-Result:
#
# lr: 0.000100 | loss: 0.0401 (0.0496) | loss_classifier: 0.0139 (0.0170) | loss_box_reg: 0.0252 (0.0304) | loss_objectness: 0.0005 (0.0006) | loss_rpn_box_reg: 0.0009 (0.0016) | time -> 1.1615
#
# 6-epoch number 176From Batch  51-Result:
#
# lr: 0.000100 | loss: 0.0401 (0.0491) | loss_classifier: 0.0146 (0.0168) | loss_box_reg: 0.0258 (0.0300) | loss_objectness: 0.0003 (0.0007) | loss_rpn_box_reg: 0.0010 (0.0016) | time -> 1.1188
#
# 6-epoch number 176From Batch  61-Result:
#
# lr: 0.000100 | loss: 0.0396 (0.0477) | loss_classifier: 0.0130 (0.0163) | loss_box_reg: 0.0239 (0.0292) | loss_objectness: 0.0003 (0.0008) | loss_rpn_box_reg: 0.0007 (0.0014) | time -> 1.1680
#
# 6-epoch number 176From Batch  71-Result:
#
# lr: 0.000100 | loss: 0.0368 (0.0475) | loss_classifier: 0.0121 (0.0160) | loss_box_reg: 0.0229 (0.0292) | loss_objectness: 0.0001 (0.0008) | loss_rpn_box_reg: 0.0008 (0.0014) | time -> 1.1573
#
# 6-epoch number 176From Batch  81-Result:
#
# lr: 0.000100 | loss: 0.0458 (0.0483) | loss_classifier: 0.0142 (0.0164) | loss_box_reg: 0.0296 (0.0295) | loss_objectness: 0.0001 (0.0009) | loss_rpn_box_reg: 0.0009 (0.0016) | time -> 1.1226
#
# 6-epoch number 176From Batch  91-Result:
#
# lr: 0.000100 | loss: 0.0402 (0.0478) | loss_classifier: 0.0147 (0.0161) | loss_box_reg: 0.0250 (0.0292) | loss_objectness: 0.0002 (0.0009) | loss_rpn_box_reg: 0.0011 (0.0016) | time -> 1.1679
#
# 6-epoch number 176From Batch 101-Result:
#
# lr: 0.000100 | loss: 0.0362 (0.0479) | loss_classifier: 0.0140 (0.0161) | loss_box_reg: 0.0244 (0.0293) | loss_objectness: 0.0005 (0.0009) | loss_rpn_box_reg: 0.0010 (0.0016) | time -> 1.2288
#
# 6-epoch number 176From Batch 111-Result:
#
# lr: 0.000100 | loss: 0.0417 (0.0478) | loss_classifier: 0.0131 (0.0161) | loss_box_reg: 0.0282 (0.0291) | loss_objectness: 0.0003 (0.0009) | loss_rpn_box_reg: 0.0016 (0.0017) | time -> 1.1919
#
# 6-epoch number 176From Batch 121-Result:
#
# lr: 0.000100 | loss: 0.0385 (0.0478) | loss_classifier: 0.0123 (0.0164) | loss_box_reg: 0.0257 (0.0289) | loss_objectness: 0.0001 (0.0009) | loss_rpn_box_reg: 0.0010 (0.0016) | time -> 1.1487
#
# 6-epoch number 176From Batch 131-Result:
#
# lr: 0.000100 | loss: 0.0463 (0.0485) | loss_classifier: 0.0132 (0.0166) | loss_box_reg: 0.0291 (0.0293) | loss_objectness: 0.0001 (0.0010) | loss_rpn_box_reg: 0.0009 (0.0017) | time -> 1.1699
#
# 6-epoch number 176From Batch 141-Result:
#
# lr: 0.000100 | loss: 0.0570 (0.0491) | loss_classifier: 0.0188 (0.0167) | loss_box_reg: 0.0344 (0.0297) | loss_objectness: 0.0005 (0.0010) | loss_rpn_box_reg: 0.0014 (0.0017) | time -> 1.1464
#
# 6-epoch number 176From Batch 151-Result:
#
# lr: 0.000100 | loss: 0.0489 (0.0493) | loss_classifier: 0.0163 (0.0166) | loss_box_reg: 0.0300 (0.0299) | loss_objectness: 0.0003 (0.0010) | loss_rpn_box_reg: 0.0011 (0.0017) | time -> 1.1362
#
# 6-epoch number 176From Batch 161-Result:
#
# lr: 0.000100 | loss: 0.0472 (0.0489) | loss_classifier: 0.0157 (0.0165) | loss_box_reg: 0.0290 (0.0299) | loss_objectness: 0.0001 (0.0010) | loss_rpn_box_reg: 0.0009 (0.0016) | time -> 1.0913
#
# 6-epoch number 176From Batch 171-Result:
#
# lr: 0.000100 | loss: 0.0399 (0.0487) | loss_classifier: 0.0131 (0.0163) | loss_box_reg: 0.0258 (0.0298) | loss_objectness: 0.0001 (0.0010) | loss_rpn_box_reg: 0.0008 (0.0016) | time -> 1.0978
#
# 6-epoch number 176From Batch 176-Result:
#
# lr: 0.000100 | loss: 0.0333 (0.0482) | loss_classifier: 0.0117 (0.0162) | loss_box_reg: 0.0216 (0.0294) | loss_objectness: 0.0001 (0.0009) | loss_rpn_box_reg: 0.0008 (0.0016) | time -> 1.1110
# 6-epoch number  total time: 0:03:23 (1.1551 s / picture)
# creating index...
# index created!
#
# Testing Process: 22From Batch  1-Result:
#
# model_time: 0.6675 (0.6675) | eval_time: 0.0058 (0.0058) | time -> 1.2304
#
# Testing Process: 22From Batch 22-Result:
#
# model_time: 0.4275 (0.5167) | eval_time: 0.0033 (0.0037) | time -> 0.5340
# Testing Process:  total time: 0:00:12 (0.5670 s / picture)
#
# Test Statistics: model_time: 0.4275 (0.5167) | eval_time: 0.0033 (0.0037)
#
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.571
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.713
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.689
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.486
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.597
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.812
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.545
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.596
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.596
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.515
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.608
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.822
#
# 7-epoch number 176From Batch   1-Result:
#
# lr: 0.000010 | loss: 0.0638 (0.0638) | loss_classifier: 0.0178 (0.0178) | loss_box_reg: 0.0452 (0.0452) | loss_objectness: 0.0000 (0.0000) | loss_rpn_box_reg: 0.0008 (0.0008) | time -> 2.1057
#
# 7-epoch number 176From Batch  11-Result:
#
# lr: 0.000010 | loss: 0.0427 (0.0473) | loss_classifier: 0.0146 (0.0154) | loss_box_reg: 0.0248 (0.0285) | loss_objectness: 0.0007 (0.0015) | loss_rpn_box_reg: 0.0009 (0.0019) | time -> 1.3420
#
# 7-epoch number 176From Batch  21-Result:
#
# lr: 0.000010 | loss: 0.0427 (0.0483) | loss_classifier: 0.0146 (0.0156) | loss_box_reg: 0.0248 (0.0296) | loss_objectness: 0.0007 (0.0015) | loss_rpn_box_reg: 0.0013 (0.0017) | time -> 1.1662
#
# 7-epoch number 176From Batch  31-Result:
#
# lr: 0.000010 | loss: 0.0441 (0.0484) | loss_classifier: 0.0174 (0.0165) | loss_box_reg: 0.0252 (0.0294) | loss_objectness: 0.0001 (0.0011) | loss_rpn_box_reg: 0.0009 (0.0014) | time -> 1.0786
#
# 7-epoch number 176From Batch  41-Result:
#
# lr: 0.000010 | loss: 0.0365 (0.0482) | loss_classifier: 0.0141 (0.0160) | loss_box_reg: 0.0233 (0.0298) | loss_objectness: 0.0001 (0.0008) | loss_rpn_box_reg: 0.0009 (0.0015) | time -> 1.1219
#
# 7-epoch number 176From Batch  51-Result:
#
# lr: 0.000010 | loss: 0.0342 (0.0485) | loss_classifier: 0.0107 (0.0161) | loss_box_reg: 0.0228 (0.0301) | loss_objectness: 0.0001 (0.0010) | loss_rpn_box_reg: 0.0009 (0.0014) | time -> 1.0999
#
# 7-epoch number 176From Batch  61-Result:
#
# lr: 0.000010 | loss: 0.0572 (0.0513) | loss_classifier: 0.0186 (0.0172) | loss_box_reg: 0.0340 (0.0313) | loss_objectness: 0.0005 (0.0010) | loss_rpn_box_reg: 0.0010 (0.0018) | time -> 1.0739
#
# 7-epoch number 176From Batch  71-Result:
#
# lr: 0.000010 | loss: 0.0474 (0.0512) | loss_classifier: 0.0189 (0.0175) | loss_box_reg: 0.0264 (0.0309) | loss_objectness: 0.0007 (0.0010) | loss_rpn_box_reg: 0.0015 (0.0019) | time -> 1.1157
#
# 7-epoch number 176From Batch  81-Result:
#
# lr: 0.000010 | loss: 0.0417 (0.0518) | loss_classifier: 0.0157 (0.0177) | loss_box_reg: 0.0246 (0.0311) | loss_objectness: 0.0007 (0.0011) | loss_rpn_box_reg: 0.0018 (0.0019) | time -> 1.1592
#
# 7-epoch number 176From Batch  91-Result:
#
# lr: 0.000010 | loss: 0.0417 (0.0507) | loss_classifier: 0.0131 (0.0172) | loss_box_reg: 0.0246 (0.0306) | loss_objectness: 0.0005 (0.0011) | loss_rpn_box_reg: 0.0009 (0.0018) | time -> 1.2628
#
# 7-epoch number 176From Batch 101-Result:
#
# lr: 0.000010 | loss: 0.0371 (0.0503) | loss_classifier: 0.0128 (0.0171) | loss_box_reg: 0.0235 (0.0303) | loss_objectness: 0.0002 (0.0011) | loss_rpn_box_reg: 0.0009 (0.0018) | time -> 1.3084
#
# 7-epoch number 176From Batch 111-Result:
#
# lr: 0.000010 | loss: 0.0371 (0.0489) | loss_classifier: 0.0112 (0.0166) | loss_box_reg: 0.0257 (0.0295) | loss_objectness: 0.0002 (0.0010) | loss_rpn_box_reg: 0.0009 (0.0018) | time -> 1.2124
#
# 7-epoch number 176From Batch 121-Result:
#
# lr: 0.000010 | loss: 0.0296 (0.0481) | loss_classifier: 0.0111 (0.0163) | loss_box_reg: 0.0183 (0.0291) | loss_objectness: 0.0003 (0.0010) | loss_rpn_box_reg: 0.0007 (0.0017) | time -> 1.2014
#
# 7-epoch number 176From Batch 131-Result:
#
# lr: 0.000010 | loss: 0.0319 (0.0475) | loss_classifier: 0.0114 (0.0160) | loss_box_reg: 0.0197 (0.0288) | loss_objectness: 0.0001 (0.0010) | loss_rpn_box_reg: 0.0008 (0.0018) | time -> 1.1962
#
# 7-epoch number 176From Batch 141-Result:
#
# lr: 0.000010 | loss: 0.0409 (0.0475) | loss_classifier: 0.0138 (0.0160) | loss_box_reg: 0.0278 (0.0288) | loss_objectness: 0.0002 (0.0010) | loss_rpn_box_reg: 0.0006 (0.0017) | time -> 1.0950
#
# 7-epoch number 176From Batch 151-Result:
#
# lr: 0.000010 | loss: 0.0381 (0.0467) | loss_classifier: 0.0124 (0.0157) | loss_box_reg: 0.0276 (0.0284) | loss_objectness: 0.0001 (0.0010) | loss_rpn_box_reg: 0.0005 (0.0017) | time -> 1.0419
#
# 7-epoch number 176From Batch 161-Result:
#
# lr: 0.000010 | loss: 0.0349 (0.0463) | loss_classifier: 0.0124 (0.0156) | loss_box_reg: 0.0210 (0.0282) | loss_objectness: 0.0001 (0.0009) | loss_rpn_box_reg: 0.0006 (0.0016) | time -> 1.1207
#
# 7-epoch number 176From Batch 171-Result:
#
# lr: 0.000010 | loss: 0.0410 (0.0467) | loss_classifier: 0.0144 (0.0159) | loss_box_reg: 0.0243 (0.0284) | loss_objectness: 0.0001 (0.0009) | loss_rpn_box_reg: 0.0007 (0.0016) | time -> 1.1410
#
# 7-epoch number 176From Batch 176-Result:
#
# lr: 0.000010 | loss: 0.0455 (0.0470) | loss_classifier: 0.0152 (0.0160) | loss_box_reg: 0.0285 (0.0285) | loss_objectness: 0.0001 (0.0009) | loss_rpn_box_reg: 0.0009 (0.0016) | time -> 1.0590
# 7-epoch number  total time: 0:03:22 (1.1493 s / picture)
# creating index...
# index created!
#
# Testing Process: 22From Batch  1-Result:
#
# model_time: 0.6780 (0.6780) | eval_time: 0.0041 (0.0041) | time -> 1.1134
#
# Testing Process: 22From Batch 22-Result:
#
# model_time: 0.4340 (0.5190) | eval_time: 0.0042 (0.0044) | time -> 0.5398
# Testing Process:  total time: 0:00:12 (0.5666 s / picture)
#
# Test Statistics: model_time: 0.4340 (0.5190) | eval_time: 0.0042 (0.0044)
#
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.570
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.713
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.689
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.486
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.590
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.816
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.548
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.597
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.597
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.515
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.602
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.833
#
# 8-epoch number 176From Batch   1-Result:
#
# lr: 0.000010 | loss: 0.0461 (0.0461) | loss_classifier: 0.0142 (0.0142) | loss_box_reg: 0.0293 (0.0293) | loss_objectness: 0.0005 (0.0005) | loss_rpn_box_reg: 0.0020 (0.0020) | time -> 1.3205
#
# 8-epoch number 176From Batch  11-Result:
#
# lr: 0.000010 | loss: 0.0440 (0.0525) | loss_classifier: 0.0145 (0.0187) | loss_box_reg: 0.0244 (0.0310) | loss_objectness: 0.0005 (0.0011) | loss_rpn_box_reg: 0.0015 (0.0017) | time -> 1.1759
#
# 8-epoch number 176From Batch  21-Result:
#
# lr: 0.000010 | loss: 0.0405 (0.0469) | loss_classifier: 0.0145 (0.0163) | loss_box_reg: 0.0219 (0.0282) | loss_objectness: 0.0002 (0.0010) | loss_rpn_box_reg: 0.0012 (0.0015) | time -> 1.1498
#
# 8-epoch number 176From Batch  31-Result:
#
# lr: 0.000010 | loss: 0.0303 (0.0426) | loss_classifier: 0.0117 (0.0149) | loss_box_reg: 0.0182 (0.0257) | loss_objectness: 0.0002 (0.0008) | loss_rpn_box_reg: 0.0006 (0.0012) | time -> 1.1685
#
# 8-epoch number 176From Batch  41-Result:
#
# lr: 0.000010 | loss: 0.0324 (0.0428) | loss_classifier: 0.0117 (0.0144) | loss_box_reg: 0.0202 (0.0265) | loss_objectness: 0.0001 (0.0007) | loss_rpn_box_reg: 0.0007 (0.0013) | time -> 1.1650
#
# 8-epoch number 176From Batch  51-Result:
#
# lr: 0.000010 | loss: 0.0446 (0.0430) | loss_classifier: 0.0132 (0.0143) | loss_box_reg: 0.0286 (0.0266) | loss_objectness: 0.0002 (0.0008) | loss_rpn_box_reg: 0.0013 (0.0014) | time -> 1.1389
#
# 8-epoch number 176From Batch  61-Result:
#
# lr: 0.000010 | loss: 0.0410 (0.0425) | loss_classifier: 0.0145 (0.0142) | loss_box_reg: 0.0282 (0.0262) | loss_objectness: 0.0002 (0.0007) | loss_rpn_box_reg: 0.0011 (0.0013) | time -> 1.1448
#
# 8-epoch number 176From Batch  71-Result:
#
# lr: 0.000010 | loss: 0.0407 (0.0431) | loss_classifier: 0.0137 (0.0143) | loss_box_reg: 0.0244 (0.0265) | loss_objectness: 0.0003 (0.0009) | loss_rpn_box_reg: 0.0011 (0.0014) | time -> 1.1740
#
# 8-epoch number 176From Batch  81-Result:
#
# lr: 0.000010 | loss: 0.0435 (0.0441) | loss_classifier: 0.0150 (0.0146) | loss_box_reg: 0.0275 (0.0270) | loss_objectness: 0.0004 (0.0010) | loss_rpn_box_reg: 0.0011 (0.0015) | time -> 1.1818
#
# 8-epoch number 176From Batch  91-Result:
#
# lr: 0.000010 | loss: 0.0360 (0.0432) | loss_classifier: 0.0137 (0.0145) | loss_box_reg: 0.0200 (0.0264) | loss_objectness: 0.0004 (0.0009) | loss_rpn_box_reg: 0.0008 (0.0014) | time -> 1.1513
#
# 8-epoch number 176From Batch 101-Result:
#
# lr: 0.000010 | loss: 0.0363 (0.0433) | loss_classifier: 0.0137 (0.0147) | loss_box_reg: 0.0197 (0.0264) | loss_objectness: 0.0001 (0.0008) | loss_rpn_box_reg: 0.0007 (0.0014) | time -> 1.0980
#
# 8-epoch number 176From Batch 111-Result:
#
# lr: 0.000010 | loss: 0.0432 (0.0434) | loss_classifier: 0.0148 (0.0146) | loss_box_reg: 0.0270 (0.0265) | loss_objectness: 0.0001 (0.0008) | loss_rpn_box_reg: 0.0007 (0.0014) | time -> 1.0966
#
# 8-epoch number 176From Batch 121-Result:
#
# lr: 0.000010 | loss: 0.0461 (0.0449) | loss_classifier: 0.0148 (0.0153) | loss_box_reg: 0.0283 (0.0271) | loss_objectness: 0.0001 (0.0009) | loss_rpn_box_reg: 0.0010 (0.0016) | time -> 1.1028
#
# 8-epoch number 176From Batch 131-Result:
#
# lr: 0.000010 | loss: 0.0505 (0.0461) | loss_classifier: 0.0167 (0.0157) | loss_box_reg: 0.0341 (0.0279) | loss_objectness: 0.0001 (0.0010) | loss_rpn_box_reg: 0.0010 (0.0015) | time -> 1.1253
#
# 8-epoch number 176From Batch 141-Result:
#
# lr: 0.000010 | loss: 0.0505 (0.0466) | loss_classifier: 0.0152 (0.0158) | loss_box_reg: 0.0341 (0.0280) | loss_objectness: 0.0001 (0.0010) | loss_rpn_box_reg: 0.0013 (0.0016) | time -> 1.2241
#
# 8-epoch number 176From Batch 151-Result:
#
# lr: 0.000010 | loss: 0.0462 (0.0465) | loss_classifier: 0.0152 (0.0159) | loss_box_reg: 0.0251 (0.0280) | loss_objectness: 0.0001 (0.0010) | loss_rpn_box_reg: 0.0011 (0.0017) | time -> 1.1965
#
# 8-epoch number 176From Batch 161-Result:
#
# lr: 0.000010 | loss: 0.0462 (0.0469) | loss_classifier: 0.0161 (0.0160) | loss_box_reg: 0.0269 (0.0282) | loss_objectness: 0.0001 (0.0010) | loss_rpn_box_reg: 0.0011 (0.0016) | time -> 1.1908
#
# 8-epoch number 176From Batch 171-Result:
#
# lr: 0.000010 | loss: 0.0427 (0.0468) | loss_classifier: 0.0155 (0.0159) | loss_box_reg: 0.0263 (0.0282) | loss_objectness: 0.0001 (0.0010) | loss_rpn_box_reg: 0.0005 (0.0016) | time -> 1.2013
#
# 8-epoch number 176From Batch 176-Result:
#
# lr: 0.000010 | loss: 0.0427 (0.0467) | loss_classifier: 0.0147 (0.0159) | loss_box_reg: 0.0263 (0.0283) | loss_objectness: 0.0001 (0.0010) | loss_rpn_box_reg: 0.0005 (0.0016) | time -> 1.1152
# 8-epoch number  total time: 0:03:23 (1.1540 s / picture)
# creating index...
# index created!
#
# Testing Process: 22From Batch  1-Result:
#
# model_time: 0.6314 (0.6314) | eval_time: 0.0041 (0.0041) | time -> 0.9052
#
# Testing Process: 22From Batch 22-Result:
#
# model_time: 0.4338 (0.5172) | eval_time: 0.0036 (0.0041) | time -> 0.5397
# Testing Process:  total time: 0:00:12 (0.5557 s / picture)
#
# Test Statistics: model_time: 0.4338 (0.5172) | eval_time: 0.0036 (0.0041)
#
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.570
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.713
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.689
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.486
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.591
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.799
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.548
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.597
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.597
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.515
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.602
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.833
#
# 9-epoch number 176From Batch   1-Result:
#
# lr: 0.000010 | loss: 0.0540 (0.0540) | loss_classifier: 0.0201 (0.0201) | loss_box_reg: 0.0333 (0.0333) | loss_objectness: 0.0000 (0.0000) | loss_rpn_box_reg: 0.0006 (0.0006) | time -> 1.8313
#
# 9-epoch number 176From Batch  11-Result:
#
# lr: 0.000010 | loss: 0.0514 (0.0489) | loss_classifier: 0.0147 (0.0167) | loss_box_reg: 0.0331 (0.0299) | loss_objectness: 0.0004 (0.0006) | loss_rpn_box_reg: 0.0013 (0.0016) | time -> 1.3257
#
# 9-epoch number 176From Batch  21-Result:
#
# lr: 0.000010 | loss: 0.0504 (0.0561) | loss_classifier: 0.0147 (0.0190) | loss_box_reg: 0.0265 (0.0336) | loss_objectness: 0.0004 (0.0015) | loss_rpn_box_reg: 0.0013 (0.0021) | time -> 1.2045
#
# 9-epoch number 176From Batch  31-Result:
#
# lr: 0.000010 | loss: 0.0492 (0.0544) | loss_classifier: 0.0151 (0.0192) | loss_box_reg: 0.0265 (0.0319) | loss_objectness: 0.0004 (0.0015) | loss_rpn_box_reg: 0.0009 (0.0018) | time -> 1.1191
#
# 9-epoch number 176From Batch  41-Result:
#
# lr: 0.000010 | loss: 0.0329 (0.0489) | loss_classifier: 0.0117 (0.0174) | loss_box_reg: 0.0200 (0.0287) | loss_objectness: 0.0003 (0.0013) | loss_rpn_box_reg: 0.0005 (0.0015) | time -> 1.1634
#
# 9-epoch number 176From Batch  51-Result:
#
# lr: 0.000010 | loss: 0.0310 (0.0475) | loss_classifier: 0.0117 (0.0169) | loss_box_reg: 0.0195 (0.0278) | loss_objectness: 0.0003 (0.0012) | loss_rpn_box_reg: 0.0007 (0.0016) | time -> 1.1241
#
# 9-epoch number 176From Batch  61-Result:
#
# lr: 0.000010 | loss: 0.0444 (0.0493) | loss_classifier: 0.0143 (0.0175) | loss_box_reg: 0.0286 (0.0289) | loss_objectness: 0.0004 (0.0012) | loss_rpn_box_reg: 0.0010 (0.0018) | time -> 1.0684
#
# 9-epoch number 176From Batch  71-Result:
#
# lr: 0.000010 | loss: 0.0446 (0.0483) | loss_classifier: 0.0147 (0.0169) | loss_box_reg: 0.0291 (0.0285) | loss_objectness: 0.0005 (0.0011) | loss_rpn_box_reg: 0.0012 (0.0017) | time -> 1.1635
#
# 9-epoch number 176From Batch  81-Result:
#
# lr: 0.000010 | loss: 0.0356 (0.0472) | loss_classifier: 0.0134 (0.0165) | loss_box_reg: 0.0213 (0.0280) | loss_objectness: 0.0002 (0.0011) | loss_rpn_box_reg: 0.0010 (0.0016) | time -> 1.1907
#
# 9-epoch number 176From Batch  91-Result:
#
# lr: 0.000010 | loss: 0.0361 (0.0466) | loss_classifier: 0.0120 (0.0160) | loss_box_reg: 0.0240 (0.0280) | loss_objectness: 0.0001 (0.0010) | loss_rpn_box_reg: 0.0008 (0.0016) | time -> 1.2086
#
# 9-epoch number 176From Batch 101-Result:
#
# lr: 0.000010 | loss: 0.0466 (0.0468) | loss_classifier: 0.0128 (0.0161) | loss_box_reg: 0.0284 (0.0282) | loss_objectness: 0.0001 (0.0009) | loss_rpn_box_reg: 0.0008 (0.0015) | time -> 1.2176
#
# 9-epoch number 176From Batch 111-Result:
#
# lr: 0.000010 | loss: 0.0435 (0.0462) | loss_classifier: 0.0150 (0.0159) | loss_box_reg: 0.0267 (0.0278) | loss_objectness: 0.0003 (0.0009) | loss_rpn_box_reg: 0.0010 (0.0016) | time -> 1.1543
#
# 9-epoch number 176From Batch 121-Result:
#
# lr: 0.000010 | loss: 0.0394 (0.0456) | loss_classifier: 0.0124 (0.0157) | loss_box_reg: 0.0221 (0.0274) | loss_objectness: 0.0002 (0.0010) | loss_rpn_box_reg: 0.0009 (0.0015) | time -> 1.0766
#
# 9-epoch number 176From Batch 131-Result:
#
# lr: 0.000010 | loss: 0.0418 (0.0459) | loss_classifier: 0.0145 (0.0158) | loss_box_reg: 0.0257 (0.0276) | loss_objectness: 0.0001 (0.0010) | loss_rpn_box_reg: 0.0009 (0.0015) | time -> 1.0697
#
# 9-epoch number 176From Batch 141-Result:
#
# lr: 0.000010 | loss: 0.0439 (0.0458) | loss_classifier: 0.0125 (0.0157) | loss_box_reg: 0.0282 (0.0277) | loss_objectness: 0.0003 (0.0009) | loss_rpn_box_reg: 0.0008 (0.0015) | time -> 1.1504
#
# 9-epoch number 176From Batch 151-Result:
#
# lr: 0.000010 | loss: 0.0439 (0.0463) | loss_classifier: 0.0165 (0.0158) | loss_box_reg: 0.0284 (0.0281) | loss_objectness: 0.0004 (0.0009) | loss_rpn_box_reg: 0.0008 (0.0015) | time -> 1.1420
#
# 9-epoch number 176From Batch 161-Result:
#
# lr: 0.000010 | loss: 0.0454 (0.0464) | loss_classifier: 0.0170 (0.0159) | loss_box_reg: 0.0276 (0.0281) | loss_objectness: 0.0001 (0.0009) | loss_rpn_box_reg: 0.0008 (0.0015) | time -> 1.1288
#
# 9-epoch number 176From Batch 171-Result:
#
# lr: 0.000010 | loss: 0.0420 (0.0467) | loss_classifier: 0.0154 (0.0160) | loss_box_reg: 0.0256 (0.0282) | loss_objectness: 0.0001 (0.0009) | loss_rpn_box_reg: 0.0006 (0.0016) | time -> 1.1272
#
# 9-epoch number 176From Batch 176-Result:
#
# lr: 0.000010 | loss: 0.0410 (0.0472) | loss_classifier: 0.0149 (0.0162) | loss_box_reg: 0.0256 (0.0285) | loss_objectness: 0.0003 (0.0009) | loss_rpn_box_reg: 0.0006 (0.0016) | time -> 1.0690
# 9-epoch number  total time: 0:03:21 (1.1452 s / picture)
# creating index...
# index created!
#
# Testing Process: 22From Batch  1-Result:
#
# model_time: 0.6406 (0.6406) | eval_time: 0.0039 (0.0039) | time -> 0.9371
#
# Testing Process: 22From Batch 22-Result:
#
# model_time: 0.4327 (0.5168) | eval_time: 0.0033 (0.0037) | time -> 0.5379
# Testing Process:  total time: 0:00:12 (0.5556 s / picture)
#
# Test Statistics: model_time: 0.4327 (0.5168) | eval_time: 0.0033 (0.0037)
#
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.572
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.713
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.689
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.486
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.598
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.799
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.548
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.599
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.599
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.515
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.608
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.833
#
# 10-epoch number 176From Batch   1-Result:
#
# lr: 0.000001 | loss: 0.0406 (0.0406) | loss_classifier: 0.0120 (0.0120) | loss_box_reg: 0.0237 (0.0237) | loss_objectness: 0.0018 (0.0018) | loss_rpn_box_reg: 0.0031 (0.0031) | time -> 1.5106
#
# 10-epoch number 176From Batch  11-Result:
#
# lr: 0.000001 | loss: 0.0375 (0.0421) | loss_classifier: 0.0120 (0.0139) | loss_box_reg: 0.0226 (0.0262) | loss_objectness: 0.0002 (0.0006) | loss_rpn_box_reg: 0.0012 (0.0015) | time -> 1.1170
#
# 10-epoch number 176From Batch  21-Result:
#
# lr: 0.000001 | loss: 0.0375 (0.0435) | loss_classifier: 0.0131 (0.0140) | loss_box_reg: 0.0231 (0.0272) | loss_objectness: 0.0002 (0.0010) | loss_rpn_box_reg: 0.0008 (0.0013) | time -> 1.1177
#
# 10-epoch number 176From Batch  31-Result:
#
# lr: 0.000001 | loss: 0.0399 (0.0433) | loss_classifier: 0.0131 (0.0144) | loss_box_reg: 0.0249 (0.0264) | loss_objectness: 0.0004 (0.0009) | loss_rpn_box_reg: 0.0007 (0.0016) | time -> 1.1503
#
# 10-epoch number 176From Batch  41-Result:
#
# lr: 0.000001 | loss: 0.0482 (0.0454) | loss_classifier: 0.0144 (0.0149) | loss_box_reg: 0.0296 (0.0282) | loss_objectness: 0.0002 (0.0007) | loss_rpn_box_reg: 0.0009 (0.0016) | time -> 1.1348
#
# 10-epoch number 176From Batch  51-Result:
#
# lr: 0.000001 | loss: 0.0383 (0.0435) | loss_classifier: 0.0121 (0.0141) | loss_box_reg: 0.0251 (0.0271) | loss_objectness: 0.0001 (0.0007) | loss_rpn_box_reg: 0.0009 (0.0016) | time -> 1.1055
#
# 10-epoch number 176From Batch  61-Result:
#
# lr: 0.000001 | loss: 0.0351 (0.0434) | loss_classifier: 0.0107 (0.0140) | loss_box_reg: 0.0225 (0.0273) | loss_objectness: 0.0002 (0.0006) | loss_rpn_box_reg: 0.0007 (0.0016) | time -> 1.1724
#
# 10-epoch number 176From Batch  71-Result:
#
# lr: 0.000001 | loss: 0.0356 (0.0438) | loss_classifier: 0.0123 (0.0144) | loss_box_reg: 0.0216 (0.0271) | loss_objectness: 0.0001 (0.0006) | loss_rpn_box_reg: 0.0008 (0.0017) | time -> 1.1480
#
# 10-epoch number 176From Batch  81-Result:
#
# lr: 0.000001 | loss: 0.0437 (0.0446) | loss_classifier: 0.0138 (0.0148) | loss_box_reg: 0.0246 (0.0275) | loss_objectness: 0.0002 (0.0007) | loss_rpn_box_reg: 0.0009 (0.0017) | time -> 1.0758
#
# 10-epoch number 176From Batch  91-Result:
#
# lr: 0.000001 | loss: 0.0499 (0.0451) | loss_classifier: 0.0138 (0.0149) | loss_box_reg: 0.0283 (0.0278) | loss_objectness: 0.0003 (0.0007) | loss_rpn_box_reg: 0.0011 (0.0017) | time -> 1.0881
#
# 10-epoch number 176From Batch 101-Result:
#
# lr: 0.000001 | loss: 0.0381 (0.0447) | loss_classifier: 0.0128 (0.0149) | loss_box_reg: 0.0261 (0.0275) | loss_objectness: 0.0004 (0.0007) | loss_rpn_box_reg: 0.0013 (0.0017) | time -> 1.0992
#
# 10-epoch number 176From Batch 111-Result:
#
# lr: 0.000001 | loss: 0.0381 (0.0449) | loss_classifier: 0.0125 (0.0149) | loss_box_reg: 0.0232 (0.0276) | loss_objectness: 0.0004 (0.0007) | loss_rpn_box_reg: 0.0012 (0.0017) | time -> 1.1473
#
# 10-epoch number 176From Batch 121-Result:
#
# lr: 0.000001 | loss: 0.0403 (0.0445) | loss_classifier: 0.0141 (0.0150) | loss_box_reg: 0.0232 (0.0272) | loss_objectness: 0.0003 (0.0007) | loss_rpn_box_reg: 0.0008 (0.0016) | time -> 1.1155
#
# 10-epoch number 176From Batch 131-Result:
#
# lr: 0.000001 | loss: 0.0470 (0.0451) | loss_classifier: 0.0167 (0.0152) | loss_box_reg: 0.0272 (0.0275) | loss_objectness: 0.0004 (0.0008) | loss_rpn_box_reg: 0.0012 (0.0017) | time -> 1.1478
#
# 10-epoch number 176From Batch 141-Result:
#
# lr: 0.000001 | loss: 0.0471 (0.0450) | loss_classifier: 0.0184 (0.0153) | loss_box_reg: 0.0273 (0.0273) | loss_objectness: 0.0004 (0.0007) | loss_rpn_box_reg: 0.0012 (0.0016) | time -> 1.1524
#
# 10-epoch number 176From Batch 151-Result:
#
# lr: 0.000001 | loss: 0.0439 (0.0450) | loss_classifier: 0.0156 (0.0153) | loss_box_reg: 0.0272 (0.0274) | loss_objectness: 0.0002 (0.0007) | loss_rpn_box_reg: 0.0007 (0.0016) | time -> 1.1499
#
# 10-epoch number 176From Batch 161-Result:
#
# lr: 0.000001 | loss: 0.0398 (0.0450) | loss_classifier: 0.0131 (0.0152) | loss_box_reg: 0.0265 (0.0275) | loss_objectness: 0.0002 (0.0007) | loss_rpn_box_reg: 0.0008 (0.0016) | time -> 1.2143
#
# 10-epoch number 176From Batch 171-Result:
#
# lr: 0.000001 | loss: 0.0508 (0.0460) | loss_classifier: 0.0160 (0.0156) | loss_box_reg: 0.0304 (0.0281) | loss_objectness: 0.0002 (0.0007) | loss_rpn_box_reg: 0.0011 (0.0016) | time -> 1.2495
#
# 10-epoch number 176From Batch 176-Result:
#
# lr: 0.000001 | loss: 0.0511 (0.0462) | loss_classifier: 0.0168 (0.0157) | loss_box_reg: 0.0328 (0.0282) | loss_objectness: 0.0003 (0.0008) | loss_rpn_box_reg: 0.0010 (0.0016) | time -> 1.1989
# 10-epoch number  total time: 0:03:20 (1.1396 s / picture)
# creating index...
# index created!
#
# Testing Process: 22From Batch  1-Result:
#
# model_time: 0.6291 (0.6291) | eval_time: 0.0046 (0.0046) | time -> 0.9158
#
# Testing Process: 22From Batch 22-Result:
#
# model_time: 0.4314 (0.5155) | eval_time: 0.0036 (0.0040) | time -> 0.5363
# Testing Process:  total time: 0:00:12 (0.5529 s / picture)
#
# Test Statistics: model_time: 0.4314 (0.5155) | eval_time: 0.0036 (0.0040)
#
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.572
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.713
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.689
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.486
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.598
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.803
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.549
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.599
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.599
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.515
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.608
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.840
#
# 11-epoch number 176From Batch   1-Result:
#
# lr: 0.000001 | loss: 0.0234 (0.0234) | loss_classifier: 0.0079 (0.0079) | loss_box_reg: 0.0123 (0.0123) | loss_objectness: 0.0005 (0.0005) | loss_rpn_box_reg: 0.0026 (0.0026) | time -> 1.4853
#
# 11-epoch number 176From Batch  11-Result:
#
# lr: 0.000001 | loss: 0.0339 (0.0406) | loss_classifier: 0.0112 (0.0141) | loss_box_reg: 0.0220 (0.0249) | loss_objectness: 0.0001 (0.0002) | loss_rpn_box_reg: 0.0012 (0.0013) | time -> 1.2362
#
# 11-epoch number 176From Batch  21-Result:
#
# lr: 0.000001 | loss: 0.0397 (0.0407) | loss_classifier: 0.0132 (0.0139) | loss_box_reg: 0.0255 (0.0246) | loss_objectness: 0.0001 (0.0009) | loss_rpn_box_reg: 0.0010 (0.0013) | time -> 1.1437
#
# 11-epoch number 176From Batch  31-Result:
#
# lr: 0.000001 | loss: 0.0476 (0.0461) | loss_classifier: 0.0163 (0.0158) | loss_box_reg: 0.0271 (0.0273) | loss_objectness: 0.0004 (0.0010) | loss_rpn_box_reg: 0.0010 (0.0019) | time -> 1.1091
#
# 11-epoch number 176From Batch  41-Result:
#
# lr: 0.000001 | loss: 0.0429 (0.0434) | loss_classifier: 0.0141 (0.0146) | loss_box_reg: 0.0262 (0.0260) | loss_objectness: 0.0007 (0.0011) | loss_rpn_box_reg: 0.0010 (0.0017) | time -> 1.0952
#
# 11-epoch number 176From Batch  51-Result:
#
# lr: 0.000001 | loss: 0.0360 (0.0444) | loss_classifier: 0.0111 (0.0148) | loss_box_reg: 0.0229 (0.0267) | loss_objectness: 0.0003 (0.0011) | loss_rpn_box_reg: 0.0009 (0.0018) | time -> 1.0662
#
# 11-epoch number 176From Batch  61-Result:
#
# lr: 0.000001 | loss: 0.0441 (0.0454) | loss_classifier: 0.0157 (0.0152) | loss_box_reg: 0.0242 (0.0272) | loss_objectness: 0.0007 (0.0013) | loss_rpn_box_reg: 0.0011 (0.0017) | time -> 1.0903
#
# 11-epoch number 176From Batch  71-Result:
#
# lr: 0.000001 | loss: 0.0530 (0.0469) | loss_classifier: 0.0170 (0.0158) | loss_box_reg: 0.0298 (0.0282) | loss_objectness: 0.0003 (0.0012) | loss_rpn_box_reg: 0.0011 (0.0017) | time -> 1.1316
#
# 11-epoch number 176From Batch  81-Result:
#
# lr: 0.000001 | loss: 0.0460 (0.0468) | loss_classifier: 0.0157 (0.0157) | loss_box_reg: 0.0302 (0.0282) | loss_objectness: 0.0002 (0.0012) | loss_rpn_box_reg: 0.0010 (0.0016) | time -> 1.1556
#
# 11-epoch number 176From Batch  91-Result:
#
# lr: 0.000001 | loss: 0.0421 (0.0465) | loss_classifier: 0.0157 (0.0159) | loss_box_reg: 0.0276 (0.0279) | loss_objectness: 0.0002 (0.0011) | loss_rpn_box_reg: 0.0010 (0.0016) | time -> 1.1425
#
# 11-epoch number 176From Batch 101-Result:
#
# lr: 0.000001 | loss: 0.0375 (0.0452) | loss_classifier: 0.0120 (0.0155) | loss_box_reg: 0.0192 (0.0271) | loss_objectness: 0.0001 (0.0011) | loss_rpn_box_reg: 0.0008 (0.0015) | time -> 1.1756
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-ad9a0f7f576d> in <cell line: 4>()
#       4 for epoch in range(epochs):
#       5     # train for one epoch, printing every 10 iterations
# ----> 6     train_one_epoch(m, optimizer, tr_dl, device, epoch, print_freq = 10)
#       7     # update the learning rate
#       8     lr_scheduler.step()
#
# <ipython-input-7-7c95a31ae29e> in train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq, scaler)
#     114             lr_scheduler.step()
#     115
# --> 116         metric_logger.update(loss=losses_reduced, **loss_dict_reduced)
#     117         metric_logger.update(lr=optimizer.param_groups[0]["lr"])
#     118
#
# <ipython-input-7-7c95a31ae29e> in update(self, **kwargs)
#     239         for k, v in kwargs.items():
#     240             if isinstance(v, torch.Tensor):
# --> 241                 v = v.item()
#     242             assert isinstance(v, (float, int))
#     243             self.meters[k].update(v)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Inference

# %%
def inference(model, ts_dl, num_ims, rows, threshold = 0.3, cmap = None):

    assert cmap in ["rgb", "gray"], "Specify Picture is Black or White"
    if cmap == "rgb": cmap = "green"

    plt.figure(figsize = (20, 10))
    indekslar = [random.randint(0, len(ts_dl) - 1) for _ in range(num_ims)]

    for idx, indeks in enumerate(indekslar):
        im, _ = ts_dl.dataset[indeks]
        with torch.no_grad(): predictions = m(im.unsqueeze(0).to(device))
        img = tensor_2_im(im, inv_trans = True)
        bbox_class_names = []
        for i, (boxes, scores, labels) in enumerate(zip(predictions[0]["boxes"], predictions[0]["scores"], predictions[0]["labels"])):
            if scores > threshold:
                bbox_class_names.append(list(class_names.keys())[labels.item()])
                r, g, b = [random.randint(0, 255) for _ in range(3)]
                x, y, w, h = [round(b.item()) for b in boxes]
                cv2.rectangle(img = img, pt1 = (x, y), pt2 = (w, h), color = (r, g, b), thickness = 2)
        plt.subplot(rows, num_ims // rows, idx + 1)
        plt.imshow(img); plt.title(f"{bbox_class_names}")
        plt.axis("off")

inference(model = m, ts_dl = ts_dl, num_ims = 5, rows = 1, cmap = "rgb")
